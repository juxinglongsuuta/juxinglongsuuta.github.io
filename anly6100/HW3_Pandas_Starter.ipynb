# %% [markdown]
# **Please enter your name and student ID here.**

# %% [markdown]
# **ANLY 6100 - Data Analytics I**
#
# **Homework - Pandas**
#
# **Use Pandas to solve questions 1-5.**

# %% [markdown]
# There are two options for this assignment.
#
# ### Option 1
#
# For this assignment, you can simply run the provided code in **Q1** to get started. You do not need to download the `EmissionsData.csv` file and upload it to your Google Drive.
#
# If you choose this option, you can skip the steps for:
#
# * Connecting to Google Drive
# * Setting the current folder
#
# ### Option 2
#
# If you prefer, you may download the `EmissionsData.csv` file, upload it to your Google Drive, connect Google Colab to your Google Drive, and set the appropriate current folder.
#
# This option is also acceptable. If you choose this approach, you may need to delete or modify the provided code in **Q1**.

# %%
# Mount your drive
from google.colab import drive
drive.mount('/content/drive')

# %%
# Change current directory
# %cd "/content/drive/MyDrive/Colab Notebooks/path of the new directory"

# %%
 # Verify the current directory
# %pwd

# %%
 # Verify the current directory
# %ls

# %% [markdown]
# ## Q1. (0.5 points)
# Import the Pandas package and load the data from **EmissionsData.csv** into a dataframe called **em_df**.

# %%
# Run the following code to start if you choose option 1.
import pandas as pd
em_df=pd.read_csv("https://juxinglongsuuta.github.io/anly6100/EmissionsData.csv")
em_df.head(5)

# %% [markdown]
# ## Q2. (1 point)
#
# Sort the dataframe using the `sort_values()` function by the column '**Emission**' in descending order. Display the top 5 records.
#
# <div style="overflow-x:auto;">
# <style scoped="">
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Year</th>
#       <th>Country</th>
#       <th>Continent</th>
#       <th>Emission</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>592</th>
#       <td>2008</td>
#       <td>Qatar</td>
#       <td>Asia</td>
#       <td>48.601620</td>
#     </tr>
#     <tr>
#       <th>593</th>
#       <td>2009</td>
#       <td>Qatar</td>
#       <td>Asia</td>
#       <td>44.836401</td>
#     </tr>
#     <tr>
#       <th>595</th>
#       <td>2011</td>
#       <td>Qatar</td>
#       <td>Asia</td>
#       <td>44.018926</td>
#     </tr>
#     <tr>
#       <th>594</th>
#       <td>2010</td>
#       <td>Qatar</td>
#       <td>Asia</td>
#       <td>42.639076</td>
#     </tr>
#     <tr>
#       <th>710</th>
#       <td>2010</td>
#       <td>Trinidad And Tobago</td>
#       <td>North America</td>
#       <td>38.337841</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# Provide your answer here.

# %% [markdown]
# ## Q3.

# %% [markdown]
# ### Q3.1 (1 point)
#
# Use the `groupby()` function to group **em_df** by the '**Year**' column..

# %%
# Provide your answer here.

# %% [markdown]
# ### Q3.2 (1.5 points)
#
# Retrieve the group '**2011**' using the `get_group()` function, and sort the 2011 group dataframe by '**Emission**' in ascending order. Display the first 5 rows.

# %%
# Provide your answer here.

# %% [markdown]
# ### Q3.3 (1 point)
#
# Use the `mean()` function to calculate the average emission of all countries in the year **2011**.
#
# <div style="overflow-x:auto;">
# <style scoped="">
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Year</th>
#       <th>Country</th>
#       <th>Continent</th>
#       <th>Emission</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>51</th>
#       <td>2011</td>
#       <td>Burundi</td>
#       <td>Africa</td>
#       <td>0.021350</td>
#     </tr>
#     <tr>
#       <th>683</th>
#       <td>2011</td>
#       <td>Chad</td>
#       <td>Africa</td>
#       <td>0.043830</td>
#     </tr>
#     <tr>
#       <th>779</th>
#       <td>2011</td>
#       <td>Dem Rep Of Congo</td>
#       <td>Africa</td>
#       <td>0.050303</td>
#     </tr>
#     <tr>
#       <th>639</th>
#       <td>2011</td>
#       <td>Somalia</td>
#       <td>Africa</td>
#       <td>0.058707</td>
#     </tr>
#     <tr>
#       <th>607</th>
#       <td>2011</td>
#       <td>Rwanda</td>
#       <td>Africa</td>
#       <td>0.062874</td>
#     </tr>
#   </tbody>
# </table>
# </div>
#
# ```text
# Average: 4.904900274527919
# ```

# %%
# Provide your answer here.

# %% [markdown]
# ## Q4.

# %% [markdown]
# ### Q4.1 (2.0 points)
#
# Find the rows in `em_df` that meet the following conditions: **Year is 2010, Continent is Europe, and Emission is greater than 2**. Sort the resulting dataframe by '**Emission**' in descending order, and display the first 5 rows.

# %%
# Provide your answer here.

# %% [markdown]
# ### Q4.2 (1 point)
#
# Calculate the average emission of **the resulting dataframe from the previous conditions**.
#
# <div style="overflow-x:auto;">
# <style scoped="">
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Year</th>
#       <th>Country</th>
#       <th>Continent</th>
#       <th>Emission</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>434</th>
#       <td>2010</td>
#       <td>Luxembourg</td>
#       <td>Europe</td>
#       <td>21.635136</td>
#     </tr>
#     <tr>
#       <th>226</th>
#       <td>2010</td>
#       <td>Estonia</td>
#       <td>Europe</td>
#       <td>13.773197</td>
#     </tr>
#     <tr>
#       <th>246</th>
#       <td>2010</td>
#       <td>Faroe Islands</td>
#       <td>Europe</td>
#       <td>12.986678</td>
#     </tr>
#     <tr>
#       <th>534</th>
#       <td>2010</td>
#       <td>Norway</td>
#       <td>Europe</td>
#       <td>11.616193</td>
#     </tr>
#     <tr>
#       <th>234</th>
#       <td>2010</td>
#       <td>Finland</td>
#       <td>Europe</td>
#       <td>11.530840</td>
#     </tr>
#   </tbody>
# </table>
# </div>
#
# ```text
# Average: 7.4887038956
# ```

# %%
# Provide your answer here.

# %% [markdown]
# ## Q5.

# %% [markdown]
# ### Q5.1 (1 point)
#
# In **em_df**, create a new column called '**Emission10PMore**'. The value in this column should be 10% more than the corresponding value in the original '**Emission**' column.

# %%
# Provide your answer here.

# %% [markdown]
# ### Q5.2 (1 point)
#
# Sort the resulting dataframe by '**Emission10PMore**' in ascending order and display the first 5 rows.
#
# <div style="overflow-x:auto;">
# <style scoped="">
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Year</th>
#       <th>Country</th>
#       <th>Continent</th>
#       <th>Emission</th>
#       <th>Emission10PMore</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>50</th>
#       <td>2010</td>
#       <td>Burundi</td>
#       <td>Africa</td>
#       <td>0.020542</td>
#       <td>0.022596</td>
#     </tr>
#     <tr>
#       <th>49</th>
#       <td>2009</td>
#       <td>Burundi</td>
#       <td>Africa</td>
#       <td>0.020868</td>
#       <td>0.022954</td>
#     </tr>
#     <tr>
#       <th>51</th>
#       <td>2011</td>
#       <td>Burundi</td>
#       <td>Africa</td>
#       <td>0.021350</td>
#       <td>0.023485</td>
#     </tr>
#     <tr>
#       <th>48</th>
#       <td>2008</td>
#       <td>Burundi</td>
#       <td>Africa</td>
#       <td>0.021615</td>
#       <td>0.023777</td>
#     </tr>
#     <tr>
#       <th>681</th>
#       <td>2009</td>
#       <td>Chad</td>
#       <td>Africa</td>
#       <td>0.042689</td>
#       <td>0.046958</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# Provide your answer here.
