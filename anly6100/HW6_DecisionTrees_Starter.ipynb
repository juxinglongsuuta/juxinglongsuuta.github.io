# %% [markdown]
# **Put your name and student ID here.**

# %% [markdown]
# **ANLY 6100 - Data Analytics I**
#
# **Homework - Decision Trees**

# %% [markdown]
# Use what you have learned in Chapter 6 to analyze the following dataset. The dataset contains four fields: age, weight, height, and size. Use weight and height as features to predict the target size, which has three values: S, L, and XXXL. Build classification models using a Decision Tree classifier, and complete the following analysis.

# %% [markdown]
# There are two options for this assignment.
#
# ### Option 1
#
# For this assignment, you can simply run the provided code in **Q1** to get started. You do not need to download the `clothes_size_data.csv` file and upload it to your Google Drive.
#
# If you choose this option, you can skip the steps for:
#
# * Connecting to Google Drive
# * Setting the current folder
#
# ### Option 2
#
# If you prefer, you may download the `clothes_size_data.csv` file, upload it to your Google Drive, connect Google Colab to your Google Drive, and set the appropriate current folder.
#
# This option is also acceptable. If you choose this approach, you may need to delete or modify the provided code in **Q1**.

# %% [markdown]
# ## Q1. (0.5 points)

# %% [markdown]
# Load the CSV file using pandas.

# %%
# Provide your answer here.

# %%
# Run the following code to start if you choose option 1.
import pandas as pd
df=pd.read_csv("https://juxinglongsuuta.github.io/anly6100/clothes_size_data.csv")
df.head(5)

# %% [markdown]
# ## Q2. (1 point)

# %% [markdown]
# Generate a new dataframe with only the fields: weight, height, and size.

# %%
# Provide your answer here.

# %% [markdown]
# ## Q3. (1 point)

# %% [markdown]
# Use `LabelEncoder` to encode the target column, 'size,' from strings to numeric values.

# %%
# Provide your answer here.

# %% [markdown]
# ## Q4. (2.5 points)

# %% [markdown]
# Create a scatter plot of the entire dataset. You should obtain a figure similar to this:

# %% [markdown]
# <img width="500" src='data:image/png;base64,...'/>

# %%
# Provide your answer here.

# %% [markdown]
# ## Q5. (1 point)

# %% [markdown]
# Split the dataset into training and testing sets, using 30% of the data for testing.

# %%
# Provide your answer here.

# %% [markdown]
# ## Q6. (2 points)

# %% [markdown]
# Scale the training and testing features (X) using `StandardScaler`.

# %%
# Provide your answer here.

# %% [markdown]
# ## Q7. (3 points)

# %% [markdown]
# Use `sklearn.tree.DecisionTreeClassifier` to fit a decision tree model with `DecisionTreeClassifier(max_depth=3, min_samples_leaf=2000)`.

# %%
# Provide your answer here.

# %% [markdown]
# ## Q8. (3 points)

# %% [markdown]
# Use the decision tree model to predict the test dataset and calculate the accuracy score of the test set using `sklearn.metrics.accuracy_score`.

# %%
# Provide your answer here.

# %% [markdown]
# ## Q9. (3 points)

# %% [markdown]
# Visualize the decision tree. You should obtain a figure similar to this:

# %% [markdown]
# <img width="1000" src='data:image/png;base64,...'/>

# %%
# Provide your answer here.

# %% [markdown]
# ## Q10. (10 points)

# %% [markdown]
# Visualize the decision boundary of the decision tree model. You should obtain a figure similar to this:

# %% [markdown]
# <img width="600" src='data:image/png;base64,...'/>

# %%
# Provide your answer here.

# %% [markdown]
# ## Q11. (3 points)

# %% [markdown]
# Comment on the generated figures and prediction models. What is the shape of the boundary, and why? Is it effective? Why? Explain your judgments.

# %%
# Provide your answer here.
