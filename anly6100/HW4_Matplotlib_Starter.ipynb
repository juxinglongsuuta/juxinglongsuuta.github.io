# %% [markdown]
# **Please enter your name and student ID here.**

# %% [markdown]
# **ANLY 6100 - Data Analytics I**
#
# **Homework - Matplotlib**
#
# **Use Matplotlib to solve questions 1-5.**

# %% [markdown]
# There are two options for this assignment.
#
# ### Option 1
#
# For this assignment, you can simply run the provided code in **Q1** and **Q2** to get started. You do not need to download the data files `lifesat.csv` and `population_vs_day.csv` and upload it to your Google Drive.
#
# If you choose this option, you can skip the steps for:
#
# * Connecting to Google Drive
# * Setting the current folder
#
# ### Option 2
#
# If you prefer, you may download the data files `lifesat.csv` and `population_vs_day.csv`, upload it to your Google Drive, connect Google Colab to your Google Drive, and set the appropriate current folder.
#
# This option is also acceptable. If you choose this approach, you may need to delete or modify the provided code in **Q1** and **Q2**.

# %%
# Mount your drive
from google.colab import drive
drive.mount('/content/drive')

# %%
# Change current directory
# %cd "/content/drive/MyDrive/Colab Notebooks/ANLY6100/HW/path of the new directory"

# %%
 # Verify the current directory
# %pwd

# %%
 # Verify the current directory
# %ls

# %% [markdown]
# ## Q1. (0.25 points)
# Load the lifesat.csv file into a Pandas DataFrame, df1 .
# ## Q2. (0.25 points)
# Load the population_vs_day.csv file into a Pandas DataFrame, df2 .

# %%
# Run the following code to start if you choose option 1.
import pandas as pd
df1=pd.read_csv("https://juxinglongsuuta.github.io/anly6100/lifesat.csv")
df1.head(5)

# %%
# Run the following code to start if you choose option 1.
df2=pd.read_csv("https://juxinglongsuuta.github.io/anly6100/population_vs_day.csv")
df2.head(5)

# %%
# Provide your answer to other questions here.
