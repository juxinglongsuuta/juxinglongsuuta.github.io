# %%
print("Your real name here")
print("Your real student ID")

print("3**2")
print("3 squred")

print(3**2) # ** is squred
# Out:
# Your real name here
# Your real student ID
# 3**2
# 3 squred
# 9

# %%
# Python Programming (Language)
# Commands to computer
# comment

# languages
# English
# Spanish
# Chinese
# French

# grammar (syntax)
# words=> sentence
# OK Yes.

# words
# syntax
# one line of code, statement

# computer
# 194X US Pen
# Python Java C++ Rust

# B (Basic or Beginner)
# C
# C++
# C++++ # C# (C Sharp)
# Java

# %%
# Python Programming
# commands
# two resources
# CPU compute calculation
# Memory (RAM) data

# RAM vs hard drive
# speed 1000X

# comment
# code
print(3*4)
# code, statement

# 3 hard topics
# assignment
# function (method)
# simple vs complex resources
# Out:
# 12

# %%
print(3+4)
# print is function
# print(): function call
# 3+4: expression
# ingridients (parameters)
# console
# Out:
# 7

# %%
# assignment
a=3+4 # assignment = assignment operator a: variable
print(a)
# Out:
# 7
