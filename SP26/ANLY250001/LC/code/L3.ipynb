# %%
# strings
# a pair of ' '  "  "
# a pair of triple ''' '''   """   """
print('Your read name here') # if you do not use your real, just copy the string here, 0.2 points deducted
print("Your real student id")
print(''' section number ''')
# Out:
# Your read name here
# Your real student id
#  section number

# %%
print("""Please input your name:""")
n = input()
s = '''Hello,''' + n +", Welcome to ANLY 2500 strings!"
print(s)
# Out:
# Please input your name:
# Xinglong Ju
# Hello,Xinglong Ju, Welcome to ANLY 2500 strings!

# %%
# assignment
# function
# simple vs complex variables
r1=0.5*3.6
# code, statement
# assignment code (assignment)
# = assignment operator
# two steps:
# first step: right hand side, expression
# CPU, result data, stores into RAM
# CPU and RAM
# second step:store the address into r1
# r1 variable
print(r1)
# Out:
# 1.8

# %%
# room types
# data types
# variables:
# rule 1: letters numbers _
# rule 2: first char is not number
r1=12.3 # 101
r1=14.6 # 111
print(r1)
# Out:
# 14.6

# %%
1r=12.3 # 1r
# Out:
#   File "/tmp/ipython-input-3527380693.py", line 1
#     1r=12.3 # 1r
#     ^
# SyntaxError: invalid decimal literal

# %%
# room types
# data types
# RAM: Byte (B)
# B=>KB=>MB=>GB=>TB
# integer: 0 -1 9 ->4B
# float/double: 1.2 -0.3 1.0=> 8B
# boolean: True False =>1B
# string: "str"=> 3B "s" =>1B

# %%
r1=2+3 # 123
print(r1)
# Out:
# 5
