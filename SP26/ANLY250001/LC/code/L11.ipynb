# %%
# list range()
# list: multiple variable (data)
a=[3,6,8] # list is a big warehouse, multiple items inside it.
print(a)
# Out:
# [3, 6, 8]

# %%
print(a[0])
# Out:
# 3

# %%
print(a[1])
# Out:
# 6

# %%
a[2]=10
print(a)
# Out:
# [3, 6, 10]

# %%
# range() help us generate data
# 1 to 10
# range(start_value,end_value,step)
r=range(1,10,1) # 1 is included, 10 is not, 1-9
print(r)

b=list(r)
print(b)
# Out:
# range(1, 10)
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
r=range(1,10,2) # 1 is included, 10 is not, 1-9
print(r)

b=list(r)
print(b)
# Out:
# range(1, 10, 2)
# [1, 3, 5, 7, 9]

# %%
# Cog gear sale practice for Quiz 1

# define vars (counter/accumulator vars)
n=0 # number of orders
ntc=0 # total number of cogs sold
ntg=0 # total number of gears sold
ts=0 # total sales/sum of the subtotals
tsc=0 # total sales for cogs
tsg=0 # total sales for gears
nl1=0 # number of orders in level 1: <1000
nl2=0
nl3=0

# collect order
##################
# one/another order
n=n+1
i=f"\n\nOrder {n}"
print(i)

i=f"N cogs:"
print(i)
cstr=input()#
c=int(cstr)# float(cstr)

i=f"N gears:"
print(i)
gstr=input()
g=float(gstr)

ntc=ntc+c
ntg=ntg+g

cs=c*60 # subtotal for cogs/cog sales
gs=g*200 # subtotal for gears/gears sales
s=cs+gs # subtotal for the order/sales for the order

tsc=tsc+cs
tsg=tsg+gs
ts=ts+s # ts=ts+cs+gs

if s<1000:
  l="Below $1000"
  nl1=nl1+1
elif s<=2000:
  l="Between $1000 and $2000"
  nl2=nl2+1
elif s>2000:#else:
  l="Above $2000"
  nl3=nl3+1

i=f"Subtotal: $ {s:.2f}, Level: {l}"
print(i)


####################

##################
# one/another order
n=n+1
i=f"\n\nOrder {n}"
print(i)

i=f"N cogs:"
print(i)
cstr=input()#
c=int(cstr)# float(cstr)

i=f"N gears:"
print(i)
gstr=input()
g=float(gstr)

ntc=ntc+c
ntg=ntg+g

cs=c*60 # subtotal for cogs/cog sales
gs=g*200 # subtotal for gears/gears sales
s=cs+gs # subtotal for the order/sales for the order

tsc=tsc+cs
tsg=tsg+gs
ts=ts+s # ts=ts+cs+gs

if s<1000:
  l="Below $1000"
  nl1=nl1+1
elif s<=2000:
  l="Between $1000 and $2000"
  nl2=nl2+1
elif s>2000:#else:
  l="Above $2000"
  nl3=nl3+1

i=f"Subtotal: $ {s:.2f}, Level: {l}"
print(i)


####################

##################
# one/another order
n=n+1
i=f"\n\nOrder {n}"
print(i)

i=f"N cogs:"
print(i)
cstr=input()#
c=int(cstr)# float(cstr)

i=f"N gears:"
print(i)
gstr=input()
g=float(gstr)

ntc=ntc+c
ntg=ntg+g

cs=c*60 # subtotal for cogs/cog sales
gs=g*200 # subtotal for gears/gears sales
s=cs+gs # subtotal for the order/sales for the order

tsc=tsc+cs
tsg=tsg+gs
ts=ts+s # ts=ts+cs+gs

if s<1000:
  l="Below $1000"
  nl1=nl1+1
elif s<=2000:
  l="Between $1000 and $2000"
  nl2=nl2+1
elif s>2000:#else:
  l="Above $2000"
  nl3=nl3+1

i=f"Subtotal: $ {s:.2f}, Level: {l}"
print(i)


####################

# summary information
#
print("\n\nSummary Information")

i=f"N orders: {n}"
print(i)

i=f"N cogs sold: {ntc}"
print(i)
i=f"N gears sold: {ntg}"
print(i)

i=f"Total sales: $ {ts:.2f}"
print(i)
i=f"Total cog sales: $ {tsc:.2f}"
print(i)
i=f"Total gear sales: $ {tsg:.2f}"
print(i)

a=ts/n
i=f"Average sales: $ {a:.2f}"
print(i)

r=nl1/n
i=f"L1: {nl1}/{n}, ({r:.2%})"
print(i)

r=nl2/n
i=f"L2: {nl2}/{n}, ({r:.2%})"
print(i)

r=nl3/n
i=f"L3: {nl3}/{n}, ({r:.2%})"
print(i)
# Out:
# Order 1
# N cogs:
# 10
# N gears:
# 2
# Subtotal: $ 1000.00, Level: Between $1000 and $2000
#
#
# Order 2
# N cogs:
# 10
# N gears:
# 10
# Subtotal: $ 2600.00, Level: Above $2000
#
#
# Order 3
# N cogs:
# 1
# N gears:
# 10
# Subtotal: $ 2060.00, Level: Above $2000
#
#
# Summary Information
# N orders: 3
# N cogs sold: 21
# N gears sold: 22.0
# Total sales: $ 5660.00
# Total cog sales: $ 1260.00
# Total gear sales: $ 4400.00
# Average sales: $ 1886.67
# L1: 0/3, (0.00%)
# L2: 1/3, (33.33%)
# L3: 2/3, (66.67%)
