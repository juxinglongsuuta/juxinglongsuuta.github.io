# %%
# your name and student id here
# loop: for loop
# what is a loop? Loop is to repeaded doing things.
s = [3, 6, 9, 12] # 4 items in list s
for i in s:
  print(f"I get {i} from list s this time") # loop body repeat 4 times
  print("The loop body is excecuted one more time")
# Out:
# I get 3 from list s this time
# The loop body is excecuted one more time
# I get 6 from list s this time
# The loop body is excecuted one more time
# I get 9 from list s this time
# The loop body is excecuted one more time
# I get 12 from list s this time
# The loop body is excecuted one more time

# %%
# loops
# for loop
# while loop
# collection

# datatypes
# string
# simple var (resources)
# float/double 8B
# int 4B
# bool 1B
a=12 # int 4B

# collection (warehouse)
# list
b=[3,3.3,"aiden",True] # write [] walls
print(b)
b2=[3,6,9,3,3,3]
print(b2)

# range()
b3=range(10) # 10 integers, 0,1,...,9
b4=range(20) # 0,1,2,...,19 range(1,10,2)
# Out:
# [3, 3.3, 'aiden', True]
# [3, 6, 9, 3, 3, 3]

# %%
w1=[3,6,10]
w2=range(20) # 0,1,...,19
# for loop
n=0

n=n+20
i=f"Congrats! You doposit $20. Balance: {n:.2f}"
print(i)
# Out:
# Congrats! You doposit $20. Balance: 20.00

# %%
w1=[2,6,10]
w2=range(20) # 0,1,...,19
# for loop
n=0

for c in w1:# step 1: c=2 step 2: c=6 step 3: c=10
  print(c) # loop body
  print(c)
  # loop body


for c1 in range(5): # step 1: c1=0 step2: c1=1
 n=n+20
 i=f"Congrats! You doposit $20. Balance: {n:.2f}"
 print(i)
# Out:
# 2
# 2
# 6
# 6
# 10
# 10
# Congrats! You doposit $20. Balance: 20.00
# Congrats! You doposit $20. Balance: 40.00
# Congrats! You doposit $20. Balance: 60.00
# Congrats! You doposit $20. Balance: 80.00
# Congrats! You doposit $20. Balance: 100.00

# %%
import random
n=0

for c in range(10):
 n=n+1
 n1=random.randint(1,10)
 n2=random.randint(1,10)
 i=f"Q{n}: {n1}+{n2}=?"
 print(i)

# Access code: AAAA
# Out:
# Q1: 6+10=?
# Q2: 3+4=?
# Q3: 1+9=?
# Q4: 3+3=?
# Q5: 6+4=?
# Q6: 9+5=?
# Q7: 1+9=?
# Q8: 9+5=?
# Q9: 9+6=?
# Q10: 5+2=?
