# %%
print("Your real name here") # Use your real name and ID
print("Your student ID here")
# Out:
# Your real name here
# Your student ID here

# %%
r = 2 + 3 # This code is called assignment
print(r) # ctrl c to copy. ctrl v to paste.
# Out:
# 5

# %%
r = 2 + 3*2 # This code is called assignment
print(r)
# Out:
# 8

# %%
# code cell comment is not code
# programming lan:
# commands to computers
# grammar (syntax)

# two resources:
# RAM memory: save data
# CPU: calculation

# 3 topics
# assignment
# function
# simple vs complex resources

# %%
# function
print(3+4)
# function call
# ingredient, parameter
# console terminal
# 3+4 equations expression
print(2*3) # 2*3
# Out:
# 7
# 6

# %%
# assignment
r=4/5
# left: r: variable
# right: 4/5: expression CPU
# TWO steps in an assignment
# First step: CPU run/execute exprssion, get a result
# data, CPU stores the data into RAM automatically
# Second step: store the data into variable: r


# assignment code, assignment statement
# code, statement
# = assignment operator
# + - * / arithmetic operator
print(r)
# Out:
# 0.8

# %%
r2=5-4
print(r2)
# code
# r2: variable, room card
# 5-4: expression
# step 1: CPU run expression, get a result, 1, CPU stores 1 into RAM
# step 2: store the room number/address into r2
# variable
# Out:
# 1
