# %%
print("Input name:")
nStr=input()

print("Input age:") # age is integer
aStr=input()
a = int(aStr)

print("Input meal amount ($):")
mStr=input()
m=float(mStr)

if a<7 or a>70:
  print("Congrat! You get 50% discount!")
  print(f"You need to pay $ {m*0.5:.2f}")
else:
  print("Sorry. You do not get the discount.")
  print(f"You need to pay $ {m:.2f}")
# Out:
# Input name:
# Xinglong
# Input age:
# 71
# Input meal amount ($):
# 20
# Congrat! You get 50% discount!
# You need to pay $ 10.00

# %%
# student grades

# define import variables
# counter/accumulator variables (bank accout)
n=0 # number of stutdents
sf=0 # sum of the finals
s1=0 # sum of exam 1 grades
s2=0 # sum of exam 2 grades
na=0 # number of A's
nb=0 # number of B's
nc=0
nd=0
nf=0

############
# process one student
n=n+1

i=f"Input Student {n} Exam 1 Grade:"
print(i)
e1str=input() # string
e1=float(e1str)

i=f"Input Student {n} Exam 2 Grade:"
print(i)
e2str=input()
e2=float(e2str)

# cal final grade
fg=e1*0.4+e2*0.6
# print(fg)
# make deposits
sf=sf+fg
s1=s1+e1
s2=s2+e2

# determine letter grade
if fg>=90:
  lg="A"
  na=na+1
elif fg>=80:
  lg="B"
  nb=nb+1
elif fg>=70:
  lg="C"
  nc=nc+1
elif fg>=60:
  lg="D"
  nd=nd+1
elif fg<60:#else:
  lg="F"
  nf=nf+1

i=f"Final grade: {fg:.2f}, Letter Grade: {lg}\n"
print(i)

# process one student
n=n+1

i=f"Input Student {n} Exam 1 Grade:"
print(i)
e1str=input() # string
e1=float(e1str)

i=f"Input Student {n} Exam 2 Grade:"
print(i)
e2str=input()
e2=float(e2str)

# cal final grade
fg=e1*0.4+e2*0.6
# print(fg)
# make deposits
sf=sf+fg
s1=s1+e1
s2=s2+e2

# determine letter grade
if fg>=90:
  lg="A"
  na=na+1
elif fg>=80:
  lg="B"
  nb=nb+1
elif fg>=70:
  lg="C"
  nc=nc+1
elif fg>=60:
  lg="D"
  nd=nd+1
elif fg<60:#else:
  lg="F"
  nf=nf+1

i=f"Final grade: {fg:.2f}, Letter Grade: {lg}\n"
print(i)

# process one student
n=n+1

i=f"Input Student {n} Exam 1 Grade:"
print(i)
e1str=input() # string
e1=float(e1str)

i=f"Input Student {n} Exam 2 Grade:"
print(i)
e2str=input()
e2=float(e2str)

# cal final grade
fg=e1*0.4+e2*0.6
# print(fg)
# make deposits
sf=sf+fg
s1=s1+e1
s2=s2+e2

# determine letter grade
if fg>=90:
  lg="A"
  na=na+1
elif fg>=80:
  lg="B"
  nb=nb+1
elif fg>=70:
  lg="C"
  nc=nc+1
elif fg>=60:
  lg="D"
  nd=nd+1
elif fg<60:#else:
  lg="F"
  nf=nf+1

i=f"Final grade: {fg:.2f}, Letter Grade: {lg}\n"
print(i)

# process one student
n=n+1

i=f"Input Student {n} Exam 1 Grade:"
print(i)
e1str=input() # string
e1=float(e1str)

i=f"Input Student {n} Exam 2 Grade:"
print(i)
e2str=input()
e2=float(e2str)

# cal final grade
fg=e1*0.4+e2*0.6
# print(fg)
# make deposits
sf=sf+fg
s1=s1+e1
s2=s2+e2

# determine letter grade
if fg>=90:
  lg="A"
  na=na+1
elif fg>=80:
  lg="B"
  nb=nb+1
elif fg>=70:
  lg="C"
  nc=nc+1
elif fg>=60:
  lg="D"
  nd=nd+1
elif fg<60:#else:
  lg="F"
  nf=nf+1

i=f"Final grade: {fg:.2f}, Letter Grade: {lg}\n"
print(i)

###############

# Summary information
# total number of students
# average of the final
# average of the exam 1
# average of the exam 2
# number of students in each letter grade and the ratio
print("\n\nSummary Information")
i=f"N Students: {n}"
print(i)

a=s1/n
i=f"Average of exam 1 grades: {a:.2f}"
print(i)

a=s2/n
i=f"Average of exam 2 grades: {a:.2f}"
print(i)

a=sf/n
i=f"Average of final grades: {a:.2f}"
print(i)

r=na/n
i=f"A: {na}/{n} ({r:.2%})"
print(i)

r=nb/n
i=f"B: {nb}/{n} ({r:.2%})"
print(i)

r=nc/n
i=f"C: {nc}/{n} ({r:.2%})"
print(i)

r=nd/n
i=f"D: {nd}/{n} ({r:.2%})"
print(i)

r=nf/n
i=f"F: {nf}/{n} ({r:.2%})"
print(i)
# Out:
# Input Student 1 Exam 1 Grade:
# 96.6
# Input Student 1 Exam 2 Grade:
# 89
# Final grade: 92.04, Letter Grade: A
#
# Input Student 2 Exam 1 Grade:
# 86.6
# Input Student 2 Exam 2 Grade:
# 78.6
# Final grade: 81.80, Letter Grade: B
#
# Input Student 3 Exam 1 Grade:
# 80.1
# Input Student 3 Exam 2 Grade:
# 80.2
# Final grade: 80.16, Letter Grade: B
#
# Input Student 4 Exam 1 Grade:
# 80.1
# Input Student 4 Exam 2 Grade:
# 80.9
# Final grade: 80.58, Letter Grade: B
#
#
#
# Summary Information
# N Students: 4
# Average of exam 1 grades: 85.85
# Average of exam 2 grades: 82.18
# Average of final grades: 83.64
# A: 1/4 (25.00%)
# B: 3/4 (75.00%)
# C: 0/4 (0.00%)
# D: 0/4 (0.00%)
# F: 0/4 (0.00%)
