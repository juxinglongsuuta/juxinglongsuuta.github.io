# %%
print("Are you a member of the store? (Yes/No)")
isMStr = input()

print("Input the purchase amount:")
pAmtStr=input()
pAmtDbl=float(pAmtStr)

if isMStr=="Yes" and pAmtDbl>50.0:
  infStr=f"Congrats!\nYou are a member of the store and the purchase amount is ${pAmtDbl:.2f}.\nYou get 10% discount"
  print(infStr)
else:
  print("Sorry!\nYou do not get the 10% discount!")
# Out:
# Are you a member of the store? (Yes/No)
# Yes
# Input the purchase amount:
# 65.6
# Congrats!
# You are a member of the store and the purchase amount is $65.60.
# You get 10% discount

# %%
# math addition quiz problem
# define important variables
nq=0 # total number of questions
nc=0 # number of correct answers
nw=0 # number of wrong answers
tp=0 # total points gained

import random #
# Q1
nq=nq+1
n1=random.randint(1,10)
n2=random.randint(1,10)
infor=f"Q{nq}: {n1} + {n2} = ?"
print(infor)
astr=input()
ua=int(astr) # user answer
gt=n1+n2 # ground truth
if ua==gt:
  # correct
  print("Correct!")
  nc=nc+1
  tp=tp+2
else:
  # wrong
  print("Incorrect!")
  nw=nw+1
  tp=tp-3

# Q2
# Q1
nq=nq+1
n1=random.randint(1,10)
n2=random.randint(1,10)
infor=f"Q{nq}: {n1} + {n2} = ?"
print(infor)
astr=input()
ua=int(astr) # user answer
gt=n1+n2 # ground truth
if ua==gt:
  # correct
  print("Correct!")
  nc=nc+1
  tp=tp+2
else:
  # wrong
  print("Incorrect!")
  nw=nw+1
  tp=tp-3
# Q1
nq=nq+1
n1=random.randint(1,10)
n2=random.randint(1,10)
infor=f"Q{nq}: {n1} + {n2} = ?"
print(infor)
astr=input()
ua=int(astr) # user answer
gt=n1+n2 # ground truth
if ua==gt:
  # correct
  print("Correct!")
  nc=nc+1
  tp=tp+2
else:
  # wrong
  print("Incorrect!")
  nw=nw+1
  tp=tp-3
# Q1
nq=nq+1
n1=random.randint(1,10)
n2=random.randint(1,10)
infor=f"Q{nq}: {n1} + {n2} = ?"
print(infor)
astr=input()
ua=int(astr) # user answer
gt=n1+n2 # ground truth
if ua==gt:
  # correct
  print("Correct!")
  nc=nc+1
  tp=tp+2
else:
  # wrong
  print("Incorrect!")
  nw=nw+1
  tp=tp-3

# Q3

# Q4

# Q5

# Summary
print("Summary Information")
infor=f"N Questions: {nq}"
print(infor)
infor=f"N Correct: {nc}"
print(infor)
infor=f"N Incorrect: {nw}"
print(infor)
r=nc/nq
infor=f"Correct rate: {r:.2%}"
print(infor)
r=nw/nq
infor=f"Incorrect rate: {r:.2%}"
print(infor)
infor=f"Final points: {tp:.3f}"
print(infor)

if tp>0:
  print("Congrats!")
elif tp==0:
  print("You need to work hard!")
elif tp<0:# else:
  print("You need to work harder!!")
# Out:
# Q1: 1 + 5 = ?
# 6
# Correct!
# Q2: 10 + 7 = ?
# 16
# Incorrect!
# Q3: 5 + 10 = ?
# 15
# Correct!
# Q4: 3 + 3 = ?
# 6
# Correct!
# Summary Information
# N Questions: 4
# N Correct: 3
# N Incorrect: 1
# Correct rate: 75.00%
# Incorrect rate: 25.00%
# Final points: 3.000
# Congrats!
