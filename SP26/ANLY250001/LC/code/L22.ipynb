# %%
# %cd "/content/drive/MyDrive/Colab Notebooks/0ANLY2500SP26/LC/L22Pandas"
# Out:
# /content/drive/MyDrive/Colab Notebooks/0ANLY2500SP26/LC/L22Pandas

# %%
# %ls
# Out:
# L22.ipynb  uscity.csv

# %%
import pandas as pd

# %%
mdf=pd.read_csv("uscity.csv")
mdf
# Out:
#                id         city               county         state  population  \
# 0      1840034016     New York               Queens      New York    19268388
# 1      1840020491  Los Angeles          Los Angeles    California    11984083
# 2      1840000494      Chicago                 Cook      Illinois     8609571
# 3      1840015149        Miami           Miami-Dade       Florida     6391670
# 4      1840020925      Houston               Harris         Texas     6227666
# ...           ...          ...                  ...           ...         ...
# 31252  1840025878   Santa Cruz                Pinal       Arizona           0
# 31253  1840153017   Frankstown                Blair  Pennsylvania           0
# 31254  1840153026      Ski Gap                Blair  Pennsylvania           0
# 31255  1840153079      Sherman  Western Connecticut   Connecticut           0
# 31256  1840153147   Twin Lakes                 Mono    California           0
#
#            lat       lng stateid
# ...

# %%
# group by
r=mdf.groupby(by=["state"]) # inside r, there are many groups. Each group is a dataframe (table)

# %%
r.groups.keys()
# Out:
# dict_keys(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'District of Columbia', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico', 'New York', 'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania', 'Puerto Rico', 'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington', 'West Virginia', 'Wisconsin', 'Wyoming'])

# %%
mdf["state"].unique()
# We get the unique state names. Two ways to do this.
# Out:
# array(['New York', 'California', 'Illinois', 'Florida', 'Texas',
#        'Pennsylvania', 'Georgia', 'District of Columbia', 'Massachusetts',
#        'Arizona', 'Michigan', 'Washington', 'Minnesota', 'Colorado',
#        'Nevada', 'Maryland', 'Missouri', 'Oregon', 'Puerto Rico',
#        'Indiana', 'Ohio', 'North Carolina', 'Virginia', 'Rhode Island',
#        'Wisconsin', 'Tennessee', 'Utah', 'Oklahoma', 'Connecticut',
#        'Kentucky', 'Louisiana', 'Nebraska', 'Alabama', 'New Mexico',
#        'South Carolina', 'Iowa', 'Kansas', 'Arkansas', 'Idaho',
#        'New Jersey', 'Hawaii', 'Mississippi', 'Alaska', 'New Hampshire',
#        'North Dakota', 'Maine', 'South Dakota', 'West Virginia',
#        'Delaware', 'Montana', 'Vermont', 'Wyoming'], dtype=object)

# %%
# get one group (dataframe)
c=mdf["state"]=="Utah"
mdf[c]
# Out:
#                id              city      county state  population      lat  \
# 45     1840021383    Salt Lake City   Salt Lake  Utah     1183003  40.7776
# 72     1840020174             Provo        Utah  Utah      641732  40.2457
# 73     1840020135             Ogden       Weber  Utah      630643  41.2279
# 307    1840021559        St. George  Washington  Utah      148405  37.0758
# 326    1840021389  West Valley City   Salt Lake  Utah      138437  40.6886
# ...           ...               ...         ...   ...         ...      ...
# 31020  1840024260           Bonanza      Uintah  Utah           0  40.0304
# 31049  1840022393             Ophir      Tooele  Utah           0  40.3716
# 31083  1840033695   Cedar Highlands        Iron  Utah           0  37.6295
# 31225  1840024467  Thompson Springs       Grand  Utah           0  38.9636
# 31233  1840024370       Clear Creek      Carbon  Utah           0  39.6433
#
#             lng stateid
# 45    -111.9311      UT
# ...

# %%
# get one group
r.get_group("Utah") # is a table (dataframe)
# Out:
# /tmp/ipykernel_361/3443269713.py:2: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   r.get_group("Utah") # is a table (dataframe)
#                id              city      county state  population      lat  \
# 45     1840021383    Salt Lake City   Salt Lake  Utah     1183003  40.7776
# 72     1840020174             Provo        Utah  Utah      641732  40.2457
# 73     1840020135             Ogden       Weber  Utah      630643  41.2279
# 307    1840021559        St. George  Washington  Utah      148405  37.0758
# 326    1840021389  West Valley City   Salt Lake  Utah      138437  40.6886
# ...           ...               ...         ...   ...         ...      ...
# 31020  1840024260           Bonanza      Uintah  Utah           0  40.0304
# 31049  1840022393             Ophir      Tooele  Utah           0  40.3716
# ...

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/Colab Notebooks/0ANLY2500SP26/LC/L22Pandas'

# %%
# %ls
# Out:
# L22.ipynb  uscity.csv

# %%
import pandas as pd

# %%
mdf=pd.read_csv("uscity.csv") # . Tom's
mdf # dataframe, table
# . .
# universe.solar system.earth.usa.utah.cedar city.main street.
# mc donald's.cheese burger
# Out:
#                id         city               county         state  population  \
# 0      1840034016     New York               Queens      New York    19268388
# 1      1840020491  Los Angeles          Los Angeles    California    11984083
# 2      1840000494      Chicago                 Cook      Illinois     8609571
# 3      1840015149        Miami           Miami-Dade       Florida     6391670
# 4      1840020925      Houston               Harris         Texas     6227666
# ...           ...          ...                  ...           ...         ...
# 31252  1840025878   Santa Cruz                Pinal       Arizona           0
# 31253  1840153017   Frankstown                Blair  Pennsylvania           0
# 31254  1840153026      Ski Gap                Blair  Pennsylvania           0
# 31255  1840153079      Sherman  Western Connecticut   Connecticut           0
# 31256  1840153147   Twin Lakes                 Mono    California           0
#
#            lat       lng stateid
# ...

# %%
# groupby() belongs to dataframe (table)
# dataframe: table
# df.groupby()
# groupby() results in multiple tables
# divide a single table into small tables
# groupby(by=[])

# %%
mdf.columns
# Out:
# Index(['id', 'city', 'county', 'state', 'population', 'lat', 'lng', 'stateid'], dtype='object')

# %%
s=mdf["stateid"] #series
s
# Out:
# 0        NY
# 1        CA
# 2        IL
# 3        FL
# 4        TX
#          ..
# 31252    AZ
# 31253    PA
# 31254    PA
# 31255    CT
# 31256    CA
# Name: stateid, Length: 31257, dtype: object

# %%
s.value_counts()
# Out:
# stateid
# PA    1886
# TX    1836
# CA    1598
# IL    1456
# OH    1253
# MO    1081
# IA    1024
# IN     974
# NY     970
# FL     945
# MN     904
# OK     839
# WI     792
# NC     771
# MI     740
# KS     738
# VA     680
# GA     670
# NJ     655
# WA     633
# AR     621
# NE     593
# AL     592
# KY     552
# MD     532
# NM     520
# TN     501
# MT     495
# LA     489
# SD     482
# CO     477
# SC     473
# AZ     461
# WV     439
# MS     426
# OR     425
# ND     401
# AK     355
# UT     332
# PR     281
# ID     236
# WY     204
# CT     185
# HI     158
# NV     132
# MA     125
# VT     107
# DE      79
# ME      66
# NH      41
# RI      31
# DC       1
# Name: count, dtype: int64

# %%
ss=s.unique()
n=len(ss)
print(ss)
print(n)
# Out:
# ['NY' 'CA' 'IL' 'FL' 'TX' 'PA' 'GA' 'DC' 'MA' 'AZ' 'MI' 'WA' 'MN' 'CO'
#  'NV' 'MD' 'MO' 'OR' 'PR' 'IN' 'OH' 'NC' 'VA' 'RI' 'WI' 'TN' 'UT' 'OK'
#  'CT' 'KY' 'LA' 'NE' 'AL' 'NM' 'SC' 'IA' 'KS' 'AR' 'ID' 'NJ' 'HI' 'MS'
#  'AK' 'NH' 'ND' 'ME' 'SD' 'WV' 'DE' 'MT' 'VT' 'WY']
# 52

# %%
r=mdf.groupby(by=["stateid"])
#

# %%
r.get_group("UT") #dataframe or table
# Out:
# /tmp/ipykernel_361/4102550747.py:1: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   r.get_group("UT") #dataframe or table
#                id              city      county state  population      lat  \
# 45     1840021383    Salt Lake City   Salt Lake  Utah     1183003  40.7776
# 72     1840020174             Provo        Utah  Utah      641732  40.2457
# 73     1840020135             Ogden       Weber  Utah      630643  41.2279
# 307    1840021559        St. George  Washington  Utah      148405  37.0758
# 326    1840021389  West Valley City   Salt Lake  Utah      138437  40.6886
# ...           ...               ...         ...   ...         ...      ...
# 31020  1840024260           Bonanza      Uintah  Utah           0  40.0304
# 31049  1840022393             Ophir      Tooele  Utah           0  40.3716
# ...

# %%
#
c=r.groups.keys()
nn=len(c)
print(c)
print(nn)
# Out:
# dict_keys(['AK', 'AL', 'AR', 'AZ', 'CA', 'CO', 'CT', 'DC', 'DE', 'FL', 'GA', 'HI', 'IA', 'ID', 'IL', 'IN', 'KS', 'KY', 'LA', 'MA', 'MD', 'ME', 'MI', 'MN', 'MO', 'MS', 'MT', 'NC', 'ND', 'NE', 'NH', 'NJ', 'NM', 'NV', 'NY', 'OH', 'OK', 'OR', 'PA', 'PR', 'RI', 'SC', 'SD', 'TN', 'TX', 'UT', 'VA', 'VT', 'WA', 'WI', 'WV', 'WY'])
# 52

# %%
r=mdf.groupby(by=["stateid"])
#ss=["TX","FL","UT"]
ss=r.groups.keys()
## ss=mdf["stateid"].unique()
for sid in ss:# sid="TX" sid="FL" sid="UT"
  print(sid)
  sdf=r.get_group(sid)
  sdf.to_csv(f"{sid}.csv")
  print(sdf.head(3))
  s=sdf['population']
  tp=s.sum()
  print(tp)
# Out:
# AK
#               id       city                county   state  population  \
# 153   1840023385  Anchorage             Anchorage  Alaska      288976
# 721   1840023463  Fairbanks  Fairbanks North Star  Alaska       68976
# 1473  1840023306     Juneau                Juneau  Alaska       31794
#
#           lat       lng stateid
# 153   61.1508 -149.1091      AK
# 721   64.8353 -147.6533      AK
# 1473  58.4546 -134.1739      AK
# 755969
# AL
#              id        city     county    state  population      lat      lng  \
# 60   1840006507  Birmingham  Jefferson  Alabama      773997  33.5279 -86.7971
# 116  1840005061  Huntsville    Madison  Alabama      368074  34.6981 -86.6412
# 137  1840006009      Mobile     Mobile  Alabama      316714  30.6782 -88.1162
#
#     stateid
# 60       AL
# 116      AL
# 137      AL
# 4499400
# AR
#              id          city      county     state  population      lat  \
# 94   1840015509   Little Rock     Pulaski  Arkansas      466334  34.7256
# ...

# %%
# %ls
# Out:
# AK.csv  CT.csv  IA.csv  L22.ipynb  MN.csv  NE.csv  OH.csv  SC.csv      VA.csv
# AL.csv  DC.csv  ID.csv  LA.csv     MO.csv  NH.csv  OK.csv  SD.csv      VT.csv
# AR.csv  DE.csv  IL.csv  MA.csv     MS.csv  NJ.csv  OR.csv  TN.csv      WA.csv
# AZ.csv  FL.csv  IN.csv  MD.csv     MT.csv  NM.csv  PA.csv  TX.csv      WI.csv
# CA.csv  GA.csv  KS.csv  ME.csv     NC.csv  NV.csv  PR.csv  uscity.csv  WV.csv
# CO.csv  HI.csv  KY.csv  MI.csv     ND.csv  NY.csv  RI.csv  UT.csv      WY.csv
