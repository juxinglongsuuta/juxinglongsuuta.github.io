# %%
# if else statement
print("Input your name: ")
nStr=input()

print("Input your age:")
ageStr=input() #
ageInt=int(ageStr)

infStr=f"My name is {nStr}.\nMy age is {ageInt}."
print(infStr)

# great = 18: adult
# less than 18: not adult
if ageInt>=18:
  print("I am an adult.")
else:
  print("I am not an adult.")
# Out:
# Input your name:
# Xinglong
# Input your age:
# 17
# My name is Xinglong.
# My age is 17.
# I am not an adult.

# %%
# assignment
# counter/accumulator assignment
# assignment
# function
b1=0 # two steps: step 1=> step 2: write address to b1
# 101
print(b1)

#
b1=b1+20 # 102
# two steps: Step 1=> 102
print(b1)

# Currently, b1: 102 (20)
#
b1=b1+20 # 103 (40)
# two steps: Step 1=>
print(b1)

# Currently, b1: 103 (40)
b1=b1+50 # 104 (90)
# two steps: Step 1=>
print(b1)

b1=b1+10
print(b1)
# Out:
# 0
# 20
# 40
# 90
# 100

# %%
# - / *
b1=b1-20
print(b1)

b1=b1+10
b1=b1+10
print(b1)
# Out:
# 80
# 100

# %%
#
b1=b1*1.05
print(b1)
# Out:
# 105.0

# %%
#
b1=b1*0.9 # write
print(b1)
# Out:
# 94.5

# %%
# weight loss example

# define important vars
name=""
curw=0
p=0 # percentage
g=0 # goal
neww=0 # new wieght after each month

# collect infor
print("Input the name:")
name=input()

# month 1

# month 2

# month 3

# check the goal
# Out:
# Input the name:
# aiden
