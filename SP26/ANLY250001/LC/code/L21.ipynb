# %%
# %cd "/content/drive/MyDrive/Colab Notebooks/0ANLY2500SP26/LC/L21"
# Out:
# /content/drive/MyDrive/Colab Notebooks/0ANLY2500SP26/LC/L21

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/Colab Notebooks/0ANLY2500SP26/LC/L21'

# %%
# %ls
# Out:
# L21_LCP.ipynb  sorted.csv  tips.csv  uscity.csv

# %%
import pandas as pd

# %%
df1=pd.read_csv("tips.csv")

# %%
df1
# Out:
#       ID  total_bill   tip     sex smoker   day    time  size
# 0      1       16.99  1.01  Female     No   Sun  Dinner     2
# 1      2       10.34  1.66    Male     No   Sun  Dinner     3
# 2      3       21.01  3.50    Male     No   Sun  Dinner     3
# 3      4       23.68  3.31    Male     No   Sun  Dinner     2
# 4      5       24.59  3.61  Female     No   Sun  Dinner     4
# ..   ...         ...   ...     ...    ...   ...     ...   ...
# 239  240       29.03  5.92    Male     No   Sat  Dinner     3
# 240  241       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241  242       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242  243       17.82  1.75    Male     No   Sat  Dinner     2
# 243  244       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 8 columns]

# %%
df1.columns
# Out:
# Index(['ID', 'total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
df2=df1.sort_values(by=['total_bill',"tip"],ascending=[False,False])

# %%
df2
# Out:
#       ID  total_bill    tip     sex smoker   day    time  size
# 170  171       50.81  10.00    Male    Yes   Sat  Dinner     3
# 212  213       48.33   9.00    Male     No   Sat  Dinner     4
# 59    60       48.27   6.73    Male     No   Sat  Dinner     4
# 156  157       48.17   5.00    Male     No   Sun  Dinner     6
# 182  183       45.35   3.50    Male    Yes   Sun  Dinner     3
# ..   ...         ...    ...     ...    ...   ...     ...   ...
# 149  150        7.51   2.00    Male     No  Thur   Lunch     2
# 172  173        7.25   5.15    Male    Yes   Sun  Dinner     2
# 111  112        7.25   1.00  Female     No   Sat  Dinner     1
# 92    93        5.75   1.00  Female    Yes   Fri  Dinner     2
# 67    68        3.07   1.00  Female    Yes   Sat  Dinner     1
#
# [244 rows x 8 columns]

# %%
df1
# Out:
#       ID  total_bill   tip     sex smoker   day    time  size
# 0      1       16.99  1.01  Female     No   Sun  Dinner     2
# 1      2       10.34  1.66    Male     No   Sun  Dinner     3
# 2      3       21.01  3.50    Male     No   Sun  Dinner     3
# 3      4       23.68  3.31    Male     No   Sun  Dinner     2
# 4      5       24.59  3.61  Female     No   Sun  Dinner     4
# ..   ...         ...   ...     ...    ...   ...     ...   ...
# 239  240       29.03  5.92    Male     No   Sat  Dinner     3
# 240  241       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241  242       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242  243       17.82  1.75    Male     No   Sat  Dinner     2
# 243  244       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 8 columns]

# %%
df2.to_csv("sorted.csv",index=False)

# %%
# %ls
# Out:
# L21_LCP.ipynb  sorted.csv  tips.csv  uscity.csv

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/Colab Notebooks/0ANLY2500SP26/LC/L21'

# %%
# %ls
# Out:
# L21.ipynb  sorted.csv  tips.csv  uscity.csv

# %%
import pandas as pd

# %%
mdf=pd.read_csv("uscity.csv")
mdf # dataframe, table
# Out:
#                id         city               county         state  population  \
# 0      1840034016     New York               Queens      New York    19268388
# 1      1840020491  Los Angeles          Los Angeles    California    11984083
# 2      1840000494      Chicago                 Cook      Illinois     8609571
# 3      1840015149        Miami           Miami-Dade       Florida     6391670
# 4      1840020925      Houston               Harris         Texas     6227666
# ...           ...          ...                  ...           ...         ...
# 31252  1840025878   Santa Cruz                Pinal       Arizona           0
# 31253  1840153017   Frankstown                Blair  Pennsylvania           0
# 31254  1840153026      Ski Gap                Blair  Pennsylvania           0
# 31255  1840153079      Sherman  Western Connecticut   Connecticut           0
# 31256  1840153147   Twin Lakes                 Mono    California           0
#
#            lat       lng stateid
# ...

# %%
# filtering: table, dataframe
s="Texas" #"Utah"
c1 = mdf["state"]==s # series
df=mdf[c1]# new dataframe, new table
df.to_csv(f"{s}.csv",index=True)
df#print(df)
# Out:
#                id            city   county  state  population      lat  \
# 4      1840020925         Houston   Harris  Texas     6227666  29.7860
# 5      1840019440          Dallas   Dallas  Texas     5968322  32.7935
# 25     1840022220     San Antonio    Bexar  Texas     2096390  29.4632
# 28     1840019590          Austin   Travis  Texas     1940039  30.3005
# 52     1840020696      Fort Worth  Tarrant  Texas      963194  32.7817
# ...           ...             ...      ...    ...         ...      ...
# 31234  1840041593   Victoria Vera    Starr  Texas           0  26.3182
# 31235  1840041577     Valle Verde     Webb  Texas           0  27.6797
# 31240  1840037129     Buena Vista    Starr  Texas           0  26.2941
# 31241  1840018286        Brundage   Dimmit  Texas           0  28.5739
# 31251  1840018314  Falcon Village    Starr  Texas           0  26.5652
#
#            lng stateid
# 4     -95.3885      TX
# 5     -96.7667      TX
# 25    -98.5238      TX
# ...

# %%
ss=mdf["state"].unique()
print(ss)

n=len(ss)# length
print(f"There are {n} states.")
# Out:
# ['New York' 'California' 'Illinois' 'Florida' 'Texas' 'Pennsylvania'
#  'Georgia' 'District of Columbia' 'Massachusetts' 'Arizona' 'Michigan'
#  'Washington' 'Minnesota' 'Colorado' 'Nevada' 'Maryland' 'Missouri'
#  'Oregon' 'Puerto Rico' 'Indiana' 'Ohio' 'North Carolina' 'Virginia'
#  'Rhode Island' 'Wisconsin' 'Tennessee' 'Utah' 'Oklahoma' 'Connecticut'
#  'Kentucky' 'Louisiana' 'Nebraska' 'Alabama' 'New Mexico' 'South Carolina'
#  'Iowa' 'Kansas' 'Arkansas' 'Idaho' 'New Jersey' 'Hawaii' 'Mississippi'
#  'Alaska' 'New Hampshire' 'North Dakota' 'Maine' 'South Dakota'
#  'West Virginia' 'Delaware' 'Montana' 'Vermont' 'Wyoming']
# There are 52 states.

# %%
# %ls
# Out:
#  Alabama.csv                 Louisiana.csv         Oregon.csv
#  Alaska.csv                  Maine.csv             Pennsylvania.csv
#  Arizona.csv                 Maryland.csv         'Puerto Rico.csv'
#  Arkansas.csv                Massachusetts.csv    'Rhode Island.csv'
#  California.csv              Michigan.csv          sorted.csv
#  Colorado.csv                Minnesota.csv        'South Carolina.csv'
#  Connecticut.csv             Mississippi.csv      'South Dakota.csv'
#  Delaware.csv                Missouri.csv          Tennessee.csv
# 'District of Columbia.csv'   Montana.csv           Texas.csv
#  Florida.csv                 Nebraska.csv          tips.csv
#  Georgia.csv                 Nevada.csv            uscity.csv
#  Hawaii.csv                 'New Hampshire.csv'    Utah.csv
#  Idaho.csv                  'New Jersey.csv'       Vermont.csv
#  Illinois.csv               'New Mexico.csv'       Virginia.csv
#  Indiana.csv                'New York.csv'         Washington.csv
# ...

# %%
# loop: for loop
#ss=["Texas","Utah","Maine"]
for s in ss: ## ss: collection, s: placeholder s="Texas"
  print(f"\n\nWe are processing State: {s}")
  c1=mdf["state"]==s
  df=mdf[c1]
  #df.to_csv(f"{s}.csv",index=False)
  n=len(df)
  print(f"There are {n} cities in {s}.")
  ndf=df.sort_values(by=["population"],ascending=[False])
  df1=ndf.head(1)
  print(f"The city with largest population in {s} is:")
  print(df1)
  #print(df)
# Out:
# We are processing State: New York
# There are 970 cities in New York.
# The city with largest population in New York is:
#            id      city  county     state  population      lat      lng  \
# 0  1840034016  New York  Queens  New York    19268388  40.6943 -73.9249
#
#   stateid
# 0      NY
#
#
# We are processing State: California
# There are 1598 cities in California.
# The city with largest population in California is:
#            id         city       county       state  population      lat  \
# 1  1840020491  Los Angeles  Los Angeles  California    11984083  34.1141
#
#         lng stateid
# 1 -118.4068      CA
#
#
# We are processing State: Illinois
# There are 1456 cities in Illinois.
# The city with largest population in Illinois is:
#            id     city county     state  population      lat      lng stateid
# 2  1840000494  Chicago   Cook  Illinois     8609571  41.8375 -87.6866      IL
#
#
# We are processing State: Florida
# There are 945 cities in Florida.
# ...
