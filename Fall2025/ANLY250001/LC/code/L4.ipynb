# %%
# some functions
print("Please input your name:")

nStr=input() # return or result in or prduce a string

print('Please input your age:')
ageStr =input() # it is a string

# convert string into integer
ageInt=int(ageStr)

newAgeInt = ageInt+1 # age after one year

inforStr = "The name is "+nStr +". " + "The currrent age is "+ageStr+". "+ 'The new age is ' +str(newAgeInt) # This is one line.

print(inforStr)
# Out:
# Please input your name:
# Xinglong
# Please input your age:
# 30
# The name is Xinglong. The currrent age is 30. The new age is 31

# %%
# How define variable?
# 1. letter numbers _
# 2. The first char should be a letter or _ (NOT a number)
age1 = 20
print(age1)
# Out:
# 20

# %%
_age1 = 19
print(_age1)
# Out:
# 19

# %%
1age = 20 # syntax
# Out:
#   File "/tmp/ipython-input-2455107249.py", line 1
#     1age = 20
#     ^
# SyntaxError: invalid decimal literal

# %%
# invalid
age# = 20
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2840128420.py in <cell line: 0>()
#       1 # invalid
# ----> 2 age# = 20
#
# NameError: name 'age' is not defined

# %%
# = assignment operator
# arithmetic operators
# + - * / ** // %
# // integer division
# % remainder
r1 = 10/3 # code, statement, assginment
# 10/3 expression CPU
# RAM store data
print(r1) # print

r1=10//3 #
print(r1)

r2=10%3# left over after integer divsion
print(r2)
# Out:
# 3.3333333333333335
# 3
# 1

# %%
r1=5/3
print(r1)
# Out:
# 1.6666666666666667

# %%
r1=5//3
print(r1)
# Out:
# 1

# %%
r1=5%3
print(r1)
# Out:
# 2

# %%
# if a number is even or odd
print(5%2)
# Out:
# 1

# %%
print(4%2)
# Out:
# 0

# %%
# string format function
# produce a string
p1 = 0.12344 #
m1=123.699
g1=86.66

print(p1)
print(m1)
print(g1)

s1=f"The interest rate is: {p1:.2%} \n\n\n   Balance is: {m1} \n\t\t         Grade {g1:.6f}"
print(s1)
# special char \n: go to next line \t: tab
# Out:
# 0.12344
# 123.699
# 86.66
# The interest rate is: 12.34%
#
#
#    Balance is: 123.699
# 		         Grade 86.660000
