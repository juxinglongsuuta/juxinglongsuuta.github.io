# %%
# ctrl v to paste the path
# %cd "/content/drive/MyDrive/Colab Notebooks/ANLY2500_01_Fall2025/LC/L17"
# Out:
# /content/drive/MyDrive/Colab Notebooks/ANLY2500_01_Fall2025/LC/L17

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/Colab Notebooks/ANLY2500_01_Fall2025/LC/L17'

# %%
# %ls
# Out:
# L17_LCP.ipynb  top10rows.csv  top10rows_NoIndex.csv  us-cities-top-1k.csv

# %%
import pandas as pd

# %%
df1=pd.read_csv("us-cities-top-1k.csv")
#print(df1)
df1 # print(df1)
# Out:
#               City           State  Population        lat         lon
# 0       Marysville      Washington       63269  48.051764 -122.177082
# 1           Perris      California       72326  33.782519 -117.228648
# 2        Cleveland            Ohio      390113  41.499320  -81.694361
# 3        Worcester   Massachusetts      182544  42.262593  -71.802293
# 4         Columbia  South Carolina      133358  34.000710  -81.034814
# ..             ...             ...         ...        ...         ...
# 995  West New York      New Jersey       52122  40.787879  -74.014306
# 996        Everett   Massachusetts       42935  42.408430  -71.053663
# 997         Linden      New Jersey       41301  40.622048  -74.244590
# 998      Asheville  North Carolina       87236  35.595058  -82.551487
# 999        Compton      California       97877  33.895849 -118.220071
#
# [1000 rows x 5 columns]

# %%
# head() tail()
df=df1.head(10)
print(df)
# Out:
#          City           State  Population        lat         lon
# 0  Marysville      Washington       63269  48.051764 -122.177082
# 1      Perris      California       72326  33.782519 -117.228648
# 2   Cleveland            Ohio      390113  41.499320  -81.694361
# 3   Worcester   Massachusetts      182544  42.262593  -71.802293
# 4    Columbia  South Carolina      133358  34.000710  -81.034814
# 5   Waterbury     Connecticut      109676  41.558153  -73.051496
# 6       Eagan       Minnesota       65453  44.804132  -93.166886
# 7  Southfield        Michigan       73006  42.473369  -83.221873
# 8   Lafayette       Louisiana      124276  30.224090  -92.019843
# 9  Boise City           Idaho      214237  43.618710 -116.214607

# %%
df.to_csv("top10rows.csv",index=True) # save to file
df.to_csv("top10rows_NoIndex.csv",index=False)

# %%
# %ls
# Out:
# L17_LCP.ipynb  top10rows.csv  top10rows_NoIndex.csv  us-cities-top-1k.csv

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/Colab Notebooks/ANLY2500_01_Fall2025/LC/L17'

# %%
# %ls
# Out:
# L17_LCP.ipynb  top10rows.csv  top10rows_NoIndex.csv  us-cities-top-1k.csv

# %%
import pandas as pd
# file, module, library, package
#

# %%
df1=pd.read_csv('us-cities-top-1k.csv')
# table, dataframe
# . 's Tom's
# Universe.Earth.USA.Utah.CedarCity.115Main.MD.fries

# %%
# print(df1)
df1
# Out:
#               City           State  Population        lat         lon
# 0       Marysville      Washington       63269  48.051764 -122.177082
# 1           Perris      California       72326  33.782519 -117.228648
# 2        Cleveland            Ohio      390113  41.499320  -81.694361
# 3        Worcester   Massachusetts      182544  42.262593  -71.802293
# 4         Columbia  South Carolina      133358  34.000710  -81.034814
# ..             ...             ...         ...        ...         ...
# 995  West New York      New Jersey       52122  40.787879  -74.014306
# 996        Everett   Massachusetts       42935  42.408430  -71.053663
# 997         Linden      New Jersey       41301  40.622048  -74.244590
# 998      Asheville  North Carolina       87236  35.595058  -82.551487
# 999        Compton      California       97877  33.895849 -118.220071
#
# [1000 rows x 5 columns]

# %%
print(df1)
# Out:
#               City           State  Population        lat         lon
# 0       Marysville      Washington       63269  48.051764 -122.177082
# 1           Perris      California       72326  33.782519 -117.228648
# 2        Cleveland            Ohio      390113  41.499320  -81.694361
# 3        Worcester   Massachusetts      182544  42.262593  -71.802293
# 4         Columbia  South Carolina      133358  34.000710  -81.034814
# ..             ...             ...         ...        ...         ...
# 995  West New York      New Jersey       52122  40.787879  -74.014306
# 996        Everett   Massachusetts       42935  42.408430  -71.053663
# 997         Linden      New Jersey       41301  40.622048  -74.244590
# 998      Asheville  North Carolina       87236  35.595058  -82.551487
# 999        Compton      California       97877  33.895849 -118.220071
#
# [1000 rows x 5 columns]

# %%
# head tail
# describe
df2=df1.head(3) # create a new table
print(df2)
# Out:
#          City       State  Population        lat         lon
# 0  Marysville  Washington       63269  48.051764 -122.177082
# 1      Perris  California       72326  33.782519 -117.228648
# 2   Cleveland        Ohio      390113  41.499320  -81.694361

# %%
# to_csv()
df2.to_csv("d2.csv",index=True)

# %%
df2.to_csv("d3.csv",index=False)

# %%
# %ls
# Out:
# d2.csv  L17_01.ipynb   top10rows_NoIndex.csv
# d3.csv  top10rows.csv  us-cities-top-1k.csv

# %%
df1.describe()
# Out:
#          Population          lat          lon
# count  1.000000e+03  1000.000000  1000.000000
# mean   1.311324e+05    37.338241   -96.483023
# std    3.416902e+05     5.279127    17.024468
# min    3.687700e+04    21.306944  -157.858333
# 25%    4.969775e+04    33.748627  -116.959608
# 50%    6.820700e+04    37.768557   -93.238834
# 75%    1.098850e+05    41.618357   -82.171804
# max    8.405837e+06    61.218056   -70.255326

# %%
df1
# Out:
#               City           State  Population        lat         lon
# 0       Marysville      Washington       63269  48.051764 -122.177082
# 1           Perris      California       72326  33.782519 -117.228648
# 2        Cleveland            Ohio      390113  41.499320  -81.694361
# 3        Worcester   Massachusetts      182544  42.262593  -71.802293
# 4         Columbia  South Carolina      133358  34.000710  -81.034814
# ..             ...             ...         ...        ...         ...
# 995  West New York      New Jersey       52122  40.787879  -74.014306
# 996        Everett   Massachusetts       42935  42.408430  -71.053663
# 997         Linden      New Jersey       41301  40.622048  -74.244590
# 998      Asheville  North Carolina       87236  35.595058  -82.551487
# 999        Compton      California       97877  33.895849 -118.220071
#
# [1000 rows x 5 columns]

# %%
[1,2,3]
# Out:
# [1, 2, 3]

# %%
df1.columns
# Out:
# Index(['City', 'State', 'Population', 'lat', 'lon'], dtype='object')

# %%
df1
# Out:
#               City           State  Population        lat         lon
# 0       Marysville      Washington       63269  48.051764 -122.177082
# 1           Perris      California       72326  33.782519 -117.228648
# 2        Cleveland            Ohio      390113  41.499320  -81.694361
# 3        Worcester   Massachusetts      182544  42.262593  -71.802293
# 4         Columbia  South Carolina      133358  34.000710  -81.034814
# ..             ...             ...         ...        ...         ...
# 995  West New York      New Jersey       52122  40.787879  -74.014306
# 996        Everett   Massachusetts       42935  42.408430  -71.053663
# 997         Linden      New Jersey       41301  40.622048  -74.244590
# 998      Asheville  North Carolina       87236  35.595058  -82.551487
# 999        Compton      California       97877  33.895849 -118.220071
#
# [1000 rows x 5 columns]

# %%
df1.columns
# Out:
# Index(['City', 'State', 'Population', 'lat', 'lon'], dtype='object')

# %%
df2=df1[['Population','State','City','State']] # indexer operator
# int float bool

# %%
df2.to_csv("D2.csv",index=False)

# %%
# *
[1,2]*3
# Out:
# [1, 2, 1, 2, 1, 2]
