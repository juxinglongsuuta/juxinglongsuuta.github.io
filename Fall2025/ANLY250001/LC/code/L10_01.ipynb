# %%
print("Input name:")
nStr=input()

print("Input age:") # age is integer
aStr=input()
a = int(aStr)

print("Input meal amount ($):")
mStr=input()
m=float(mStr)

if a<7 or a>70:
  print("Congrat! You get 50% discount!")
  print(f"You need to pay $ {m*0.5:.2f}")
else:
  print("Sorry. You do not get the discount.")
  print(f"You need to pay $ {m:.2f}")
# Out:
# Input name:
# Xinglong
# Input age:
# 71
# Input meal amount ($):
# 20
# Congrat! You get 50% discount!
# You need to pay $ 10.00

# %%
# Math addition quiz
# define variables
nQ=0 # number of questions counter/accumulator varaible
nC=0 # number of correct
nW=0 # number of wrong
s=0 # final/total score

# show the questions and grade the questions

import random #

# Q1
n1=random.randint(1,10) # Tom's
n2=random.randint(1,10)
gt=n1+n2 # gt: ground truth
nQ=nQ+1
i=f"Question {nQ}: {n1} + {n2} = ?"
print(i)
aStr=input()
a=int(aStr) # user answer
if gt==a:
  # correct
  print("Correct! Gain 2 points!")
  nC=nC+1 #
  s=s+2
else:
  # wrong
  print("Wrong! Lose 3 points!")
  nW=nW+1
  s=s-3

# Q2
n1=random.randint(1,10) # Tom's
n2=random.randint(1,10)
gt=n1+n2 # gt: ground truth
nQ=nQ+1
i=f"Question {nQ}: {n1} + {n2} = ?"
print(i)
aStr=input()
a=int(aStr) # user answer
if gt==a:
  # correct
  print("Correct! Gain 2 points!")
  nC=nC+1 #
  s=s+2
else:
  # wrong
  print("Wrong! Lose 3 points!")
  nW=nW+1
  s=s-3

# Q3
n1=random.randint(1,10) # Tom's
n2=random.randint(1,10)
gt=n1+n2 # gt: ground truth
nQ=nQ+1
i=f"Question {nQ}: {n1} + {n2} = ?"
print(i)
aStr=input()
a=int(aStr) # user answer
if gt==a:
  # correct
  print("Correct! Gain 2 points!")
  nC=nC+1 #
  s=s+2
else:
  # wrong
  print("Wrong! Lose 3 points!")
  nW=nW+1
  s=s-3

# Q4
n1=random.randint(1,10) # Tom's
n2=random.randint(1,10)
gt=n1+n2 # gt: ground truth
nQ=nQ+1
i=f"Question {nQ}: {n1} + {n2} = ?"
print(i)
aStr=input()
a=int(aStr) # user answer
if gt==a:
  # correct
  print("Correct! Gain 2 points!")
  nC=nC+1 #
  s=s+2
else:
  # wrong
  print("Wrong! Lose 3 points!")
  nW=nW+1
  s=s-3


# show the summary inforamtion
print("\n")
print("Summary information")
i=f"Number of questions: {nQ}"
print(i)

r=nC/nQ # ratio
i=f"Correct: {nC}/{nQ}, {r:.2%}"
print(i)

# r=nW/nQ
i=f"Wrong: {nW}/{nQ}, {nW/nQ:.2%}"
print(i)

i=f"Final score: {s}"
print(i)

if s>0:
  print("Congrats! Score is positive!")
elif s==0:
  print("Score is 0!")
else:#elif s<0:
  print("Sorry! Score is negative")
# Out:
# Question 1: 4 + 1 = ?
# 2
# Wrong! Lose 3 points!
# Question 2: 6 + 3 = ?
# 9
# Correct! Gain 2 points!
# Question 3: 7 + 9 = ?
# 15
# Wrong! Lose 3 points!
# Question 4: 1 + 7 = ?
# 6
# Wrong! Lose 3 points!
#
#
# Summary information
# Number of questions: 4
# Correct: 1/4, 25.00%
# Wrong: 3/4, 75.00%
# Final score: -7
# Sorry! Score is negative
