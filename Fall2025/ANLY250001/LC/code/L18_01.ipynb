# %%
# ctrl v to paste
# %cd "/content/drive/MyDrive/Colab Notebooks/ANLY2500_01_Fall2025/LC/L18"
# Out:
# /content/drive/MyDrive/Colab Notebooks/ANLY2500_01_Fall2025/LC/L18

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %ls
# Out:
# L18_LCP.ipynb  us-cities-top-1k.csv

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/Colab Notebooks/ANLY2500_01_Fall2025/LC/L18'

# %%
import pandas as pd

# %%
df= pd.read_csv("us-cities-top-1k.csv") # ctrl c to copy
print(df)
# Out:
#               City           State  Population        lat         lon
# 0       Marysville      Washington       63269  48.051764 -122.177082
# 1           Perris      California       72326  33.782519 -117.228648
# 2        Cleveland            Ohio      390113  41.499320  -81.694361
# 3        Worcester   Massachusetts      182544  42.262593  -71.802293
# 4         Columbia  South Carolina      133358  34.000710  -81.034814
# ..             ...             ...         ...        ...         ...
# 995  West New York      New Jersey       52122  40.787879  -74.014306
# 996        Everett   Massachusetts       42935  42.408430  -71.053663
# 997         Linden      New Jersey       41301  40.622048  -74.244590
# 998      Asheville  North Carolina       87236  35.595058  -82.551487
# 999        Compton      California       97877  33.895849 -118.220071
#
# [1000 rows x 5 columns]

# %%
l=[2]*1000
print(l)
# Out:
# [2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2
# ...

# %%
df["NC1"]=l

# %%
print(df)
# Out:
#               City           State  Population        lat         lon  NC1
# 0       Marysville      Washington       63269  48.051764 -122.177082    2
# 1           Perris      California       72326  33.782519 -117.228648    2
# 2        Cleveland            Ohio      390113  41.499320  -81.694361    2
# 3        Worcester   Massachusetts      182544  42.262593  -71.802293    2
# 4         Columbia  South Carolina      133358  34.000710  -81.034814    2
# ..             ...             ...         ...        ...         ...  ...
# 995  West New York      New Jersey       52122  40.787879  -74.014306    2
# 996        Everett   Massachusetts       42935  42.408430  -71.053663    2
# 997         Linden      New Jersey       41301  40.622048  -74.244590    2
# 998      Asheville  North Carolina       87236  35.595058  -82.551487    2
# 999        Compton      California       97877  33.895849 -118.220071    2
#
# [1000 rows x 6 columns]

# %%
df["NC2"]=df["Population"]*1.03

# %%
print(df)
# Out:
#               City           State  Population        lat         lon  NC1  \
# 0       Marysville      Washington       63269  48.051764 -122.177082    2
# 1           Perris      California       72326  33.782519 -117.228648    2
# 2        Cleveland            Ohio      390113  41.499320  -81.694361    2
# 3        Worcester   Massachusetts      182544  42.262593  -71.802293    2
# 4         Columbia  South Carolina      133358  34.000710  -81.034814    2
# ..             ...             ...         ...        ...         ...  ...
# 995  West New York      New Jersey       52122  40.787879  -74.014306    2
# 996        Everett   Massachusetts       42935  42.408430  -71.053663    2
# 997         Linden      New Jersey       41301  40.622048  -74.244590    2
# 998      Asheville  North Carolina       87236  35.595058  -82.551487    2
# 999        Compton      California       97877  33.895849 -118.220071    2
#
#            NC2
# 0     65167.07
# 1     74495.78
# 2    401816.39
# ...

# %%
df.to_csv("D1.csv",index=False)

# %%
# %ls
# Out:
# D1.csv  L18_LCP.ipynb  us-cities-top-1k.csv

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/Colab Notebooks/ANLY2500_01_Fall2025/LC/L18'

# %%
# %ls
# Out:
# D1.csv  L18_01.ipynb  us-cities-top-1k.csv

# %%
import pandas as pd

# %%
df1=pd.read_csv('us-cities-top-1k.csv')

# %%
print(df1)
# Out:
#               City           State  Population        lat         lon
# 0       Marysville      Washington       63269  48.051764 -122.177082
# 1           Perris      California       72326  33.782519 -117.228648
# 2        Cleveland            Ohio      390113  41.499320  -81.694361
# 3        Worcester   Massachusetts      182544  42.262593  -71.802293
# 4         Columbia  South Carolina      133358  34.000710  -81.034814
# ..             ...             ...         ...        ...         ...
# 995  West New York      New Jersey       52122  40.787879  -74.014306
# 996        Everett   Massachusetts       42935  42.408430  -71.053663
# 997         Linden      New Jersey       41301  40.622048  -74.244590
# 998      Asheville  North Carolina       87236  35.595058  -82.551487
# 999        Compton      California       97877  33.895849 -118.220071
#
# [1000 rows x 5 columns]

# %%
print(df1.columns)
# Out:
# Index(['City', 'State', 'Population', 'lat', 'lon'], dtype='object')

# %%
# head tail
df2=df1.head(3) # Table saved in RAM

# %%
print(df2)
# Out:
#          City       State  Population        lat         lon
# 0  Marysville  Washington       63269  48.051764 -122.177082
# 1      Perris  California       72326  33.782519 -117.228648
# 2   Cleveland        Ohio      390113  41.499320  -81.694361

# %%
df2.to_csv('top3.csv',index=True)

# %%
# %ls
# Out:
# D1.csv  L18_01.ipynb  top3.csv  us-cities-top-1k.csv

# %%
df1.columns
# Out:
# Index(['City', 'State', 'Population', 'lat', 'lon'], dtype='object')

# %%
df3=df1[['State','State','City']] # [] . Table RAM

# %%
print(df3)
# Out:
#               State           State           City
# 0        Washington      Washington     Marysville
# 1        California      California         Perris
# 2              Ohio            Ohio      Cleveland
# 3     Massachusetts   Massachusetts      Worcester
# 4    South Carolina  South Carolina       Columbia
# ..              ...             ...            ...
# 995      New Jersey      New Jersey  West New York
# 996   Massachusetts   Massachusetts        Everett
# 997      New Jersey      New Jersey         Linden
# 998  North Carolina  North Carolina      Asheville
# 999      California      California        Compton
#
# [1000 rows x 3 columns]

# %%
df3.to_csv("c3.csv",index=False)

# %%
# %ls
# Out:
# c3.csv  D1.csv  L18_01.ipynb  top3.csv  us-cities-top-1k.csv

# %%
df1
# Out:
#               City           State  Population        lat         lon
# 0       Marysville      Washington       63269  48.051764 -122.177082
# 1           Perris      California       72326  33.782519 -117.228648
# 2        Cleveland            Ohio      390113  41.499320  -81.694361
# 3        Worcester   Massachusetts      182544  42.262593  -71.802293
# 4         Columbia  South Carolina      133358  34.000710  -81.034814
# ..             ...             ...         ...        ...         ...
# 995  West New York      New Jersey       52122  40.787879  -74.014306
# 996        Everett   Massachusetts       42935  42.408430  -71.053663
# 997         Linden      New Jersey       41301  40.622048  -74.244590
# 998      Asheville  North Carolina       87236  35.595058  -82.551487
# 999        Compton      California       97877  33.895849 -118.220071
#
# [1000 rows x 5 columns]

# %%
[1,2]*3
# Out:
# [1, 2, 1, 2, 1, 2]

# %%
[2.3]*10
# Out:
# [2.3, 2.3, 2.3, 2.3, 2.3, 2.3, 2.3, 2.3, 2.3, 2.3]

# %%
df1["NC1"]=[20]*1000

# %%
df1
# Out:
#               City           State  Population        lat         lon  NC1
# 0       Marysville      Washington       63269  48.051764 -122.177082   20
# 1           Perris      California       72326  33.782519 -117.228648   20
# 2        Cleveland            Ohio      390113  41.499320  -81.694361   20
# 3        Worcester   Massachusetts      182544  42.262593  -71.802293   20
# 4         Columbia  South Carolina      133358  34.000710  -81.034814   20
# ..             ...             ...         ...        ...         ...  ...
# 995  West New York      New Jersey       52122  40.787879  -74.014306   20
# 996        Everett   Massachusetts       42935  42.408430  -71.053663   20
# 997         Linden      New Jersey       41301  40.622048  -74.244590   20
# 998      Asheville  North Carolina       87236  35.595058  -82.551487   20
# 999        Compton      California       97877  33.895849 -118.220071   20
#
# [1000 rows x 6 columns]

# %%
df1["Population"]+1000 # no [] series, []: table
# Out:
# 0       64269
# 1       73326
# 2      391113
# 3      183544
# 4      134358
#         ...
# 995     53122
# 996     43935
# 997     42301
# 998     88236
# 999     98877
# Name: Population, Length: 1000, dtype: int64

# %%
df1["NC2"]=df1["Population"]*1.03 # series

# %%
df1
# Out:
#               City           State  Population        lat         lon  NC1  \
# 0       Marysville      Washington       63269  48.051764 -122.177082   20
# 1           Perris      California       72326  33.782519 -117.228648   20
# 2        Cleveland            Ohio      390113  41.499320  -81.694361   20
# 3        Worcester   Massachusetts      182544  42.262593  -71.802293   20
# 4         Columbia  South Carolina      133358  34.000710  -81.034814   20
# ..             ...             ...         ...        ...         ...  ...
# 995  West New York      New Jersey       52122  40.787879  -74.014306   20
# 996        Everett   Massachusetts       42935  42.408430  -71.053663   20
# 997         Linden      New Jersey       41301  40.622048  -74.244590   20
# 998      Asheville  North Carolina       87236  35.595058  -82.551487   20
# 999        Compton      California       97877  33.895849 -118.220071   20
#
#            NC2
# 0     65167.07
# 1     74495.78
# 2    401816.39
# ...

# %%
# sort_values()
df4=df1.sort_values(by=['Population'],ascending=[False])# by:column name RAM

# %%
df4
# Out:
#              City         State  Population        lat         lon  NC1  \
# 890      New York      New York     8405837  40.712784  -74.005941   20
# 953   Los Angeles    California     3884307  34.052234 -118.243685   20
# 594       Chicago      Illinois     2718782  41.878114  -87.629798   20
# 646       Houston         Texas     2195914  29.760427  -95.369803   20
# 53   Philadelphia  Pennsylvania     1553165  39.952584  -75.165222   20
# ..            ...           ...         ...        ...         ...  ...
# 346       Weslaco         Texas       37093  26.159519  -97.990837   20
# 722        Keizer        Oregon       37064  44.990119 -123.026208   20
# 434  Spanish Fork          Utah       36956  40.114955 -111.654923   20
# 552        Beloit     Wisconsin       36888  42.508348  -89.031777   20
# 961   Panama City       Florida       36877  30.158813  -85.660206   20
#
#             NC2
# 890  8658012.11
# 953  4000836.21
# 594  2800345.46
# 646  2261791.42
# ...

# %%
df4.to_csv("sorted.csv",index=False)

# %%
df1
# Out:
#               City           State  Population        lat         lon  NC1  \
# 0       Marysville      Washington       63269  48.051764 -122.177082   20
# 1           Perris      California       72326  33.782519 -117.228648   20
# 2        Cleveland            Ohio      390113  41.499320  -81.694361   20
# 3        Worcester   Massachusetts      182544  42.262593  -71.802293   20
# 4         Columbia  South Carolina      133358  34.000710  -81.034814   20
# ..             ...             ...         ...        ...         ...  ...
# 995  West New York      New Jersey       52122  40.787879  -74.014306   20
# 996        Everett   Massachusetts       42935  42.408430  -71.053663   20
# 997         Linden      New Jersey       41301  40.622048  -74.244590   20
# 998      Asheville  North Carolina       87236  35.595058  -82.551487   20
# 999        Compton      California       97877  33.895849 -118.220071   20
#
#            NC2
# 0     65167.07
# 1     74495.78
# 2    401816.39
# ...

# %%
df1['Population']>100000 # single column, series
# Out:
# 0      False
# 1      False
# 2       True
# 3       True
# 4       True
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: Population, Length: 1000, dtype: bool
