# %%
# strings
# a pair of ' '  "  "
# a pair of triple ''' '''   """   """
print('Your read name here') # if you do not use your real, just copy the string here, 0.2 points deducted
print("Your real student id")
print(''' section number ''')
# Out:
# Your read name here
# Your real student id
#  section number

# %%
print("""Please input your name:""")
n = input()
s = '''Hello,''' + n +", Welcome to ANLY 2500 strings!"
print(s)
# Out:
# Please input your name:
# Xinglong Ju
# Hello,Xinglong Ju, Welcome to ANLY 2500 strings!

# %%
# Assignment
# Function
# Simple and complex resource

# datatypes
# functions

# Hotel different room sizes
# datatypes (room type, size)
# RAM, Byte, KB, MB, GB, TB
# integer: whole number, -10, 0 ,1,3: 4B
# float (double): 1.0, -1.2, 3.66, 8B
# boolean: True False 1B
# string: "1.0" text 3B
# "1.0000000000" string 10 zeros 12B
# 1.0000000000 8B

# functions
# function machine
# coffeemaker(i1,i2,i3): function call
# int(i1)
# float(i2)
# str(i3)
# input()# produce string

# %%
v1=2 # int
v2=3 # int
v3 = v1+v2
print(v3)

v3=v1*v2
print(v3)
#  operators:  + - * / **

v3=v1**v2
print(v3)

v3=v1/v2
print(v3)
# Out:
# 5
# 6
# 8
# 0.6666666666666666

# %%
v1 = 1.2 # float
v2= 1.0 # float

v3 = v1-v2
print(v3)
#
# Out:
# 0.19999999999999996

# %%
print("Input your age:")
ageStr=input()#always string
print(ageStr)

ageInt=int(ageStr)
print(ageInt)
# Out:
# Input your age:
# 20
# 20
# 20
