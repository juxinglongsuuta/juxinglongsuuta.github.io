# %%
print("Your real name here") # Use your real name and ID
print("Your student ID here")
# Out:
# Your real name here
# Your student ID here

# %%
r = 2 + 3 # This code is called assignment
print(r) # ctrl c to copy. ctrl v to paste.
# Out:
# 5

# %%
r = 2 + 3*2 # This code is called assignment
print(r)
# Out:
# 8

# %%
# Python programming language
# Commands

# Two main resouces
# CPU: Calculation
# RAM (memory): store data

# 3 hard topics
# Assingment
# Function
# simple vs complex varialbes

# comments vs code
# Code (statement)

# %%
# variables and assignment
print(3**2) # function call
# Console
# print function/method
# print() function call
# 3**2 parameter, integrient ,,
# operator ** square + - / *
# 2+3 expression
print(9) # print print()
print(8)
# Out:
# 9
# 9
# 8

# %%
# variables and assignment
# = assignment operator
# variable: room card
# assignment:
v1=2 # v1 variable, = assignment operator,
# assginment code, assignment statement, assignment
# assginemt two steps
# right hand side vs left hand side
# First step: 2, CPU stores the data 2 into RAM
# Second step: Write the address/room number inot room card
# v1

# %%
print(v1) #
# Out:
# 2

# %%
v2=4**2 # code, statement, assignment,
# =
# right: 4**2: expression, CPU
# left: v2 variable
# First step:
# Second step
print(v2) #
# Out:
# 16

# %%
id(v2)
# Out:
# 11642568

# %%
id(v1)
# Out:
# 11642120
