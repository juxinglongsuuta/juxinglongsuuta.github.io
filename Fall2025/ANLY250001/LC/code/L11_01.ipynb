# %%
# list range()
# list: multiple variable (data)
a=[3,6,8] # list is a big warehouse, multiple items inside it.
print(a)
# Out:
# [3, 6, 8]

# %%
print(a[0])
# Out:
# 3

# %%
print(a[1])
# Out:
# 6

# %%
a[2]=10
print(a)
# Out:
# [3, 6, 10]

# %%
# range() help us generate data
# 1 to 10
# range(start_value,end_value,step)
r=range(1,10,1) # 1 is included, 10 is not, 1-9
print(r)

b=list(r)
print(b)
# Out:
# range(1, 10)
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
r=range(1,10,2) # 1 is included, 10 is not, 1-9
print(r)

b=list(r)
print(b)
# Out:
# range(1, 10, 2)
# [1, 3, 5, 7, 9]

# %%
# student grade problem

# define variable
n=0 # total number of student

nA=0
nB=0
nC=0
nD=0
nF=0

sumG=0 # sum of all final grades
sumGA=0 # sum of all final grades for A
sumGB=0
sumGC=0
sumGD=0
sumGF=0


# collect grade

# student 1
n=n+1# RAM
i=f"\n\nStudent {n} Exam 1 Grade:"
print(i)
e1Str=input() #
e1=float(e1Str) #

i=f"Student {n} Exam 2 Grade:"
print(i)
e2Str=input()
e2=float(e2Str)

fg=e1*0.4+e2*0.6 # final grade
sumG=sumG+fg

if fg>=90:
  lg="A" # letter grade
  nA=nA+1
  sumGA=sumGA+fg
elif fg>=80:
  lg="B"
  nB=nB+1
  sumGB=sumGB+fg
elif fg>=70:
  lg="C"
  nC=nC+1
  sumGC=sumGC+fg
elif fg>=60:
  lg='D'
  nD=nD+1
  sumGD=sumGD+fg
elif fg<60: # else:
  lg='F'
  nF=nF+1
  sumGF=sumGF+fg

i=f"Final grade: {fg:.2f}, Letter grade: {lg}"
print(i)

# student 1
n=n+1# RAM
i=f"\n\nStudent {n} Exam 1 Grade:"
print(i)
e1Str=input() #
e1=float(e1Str) #

i=f"Student {n} Exam 2 Grade:"
print(i)
e2Str=input()
e2=float(e2Str)

fg=e1*0.4+e2*0.6 # final grade
sumG=sumG+fg

if fg>=90:
  lg="A" # letter grade
  nA=nA+1
  sumGA=sumGA+fg
elif fg>=80:
  lg="B"
  nB=nB+1
  sumGB=sumGB+fg
elif fg>=70:
  lg="C"
  nC=nC+1
  sumGC=sumGC+fg
elif fg>=60:
  lg='D'
  nD=nD+1
  sumGD=sumGD+fg
elif fg<60: # else:
  lg='F'
  nF=nF+1
  sumGF=sumGF+fg

i=f"Final grade: {fg:.2f}, Letter grade: {lg}"
print(i)

# student 1
n=n+1# RAM
i=f"\n\nStudent {n} Exam 1 Grade:"
print(i)
e1Str=input() #
e1=float(e1Str) #

i=f"Student {n} Exam 2 Grade:"
print(i)
e2Str=input()
e2=float(e2Str)

fg=e1*0.4+e2*0.6 # final grade
sumG=sumG+fg

if fg>=90:
  lg="A" # letter grade
  nA=nA+1
  sumGA=sumGA+fg
elif fg>=80:
  lg="B"
  nB=nB+1
  sumGB=sumGB+fg
elif fg>=70:
  lg="C"
  nC=nC+1
  sumGC=sumGC+fg
elif fg>=60:
  lg='D'
  nD=nD+1
  sumGD=sumGD+fg
elif fg<60: # else:
  lg='F'
  nF=nF+1
  sumGF=sumGF+fg

i=f"Final grade: {fg:.2f}, Letter grade: {lg}"
print(i)

# student 1
n=n+1# RAM
i=f"\n\nStudent {n} Exam 1 Grade:"
print(i)
e1Str=input() #
e1=float(e1Str) #

i=f"Student {n} Exam 2 Grade:"
print(i)
e2Str=input()
e2=float(e2Str)

fg=e1*0.4+e2*0.6 # final grade
sumG=sumG+fg

if fg>=90:
  lg="A" # letter grade
  nA=nA+1
  sumGA=sumGA+fg
elif fg>=80:
  lg="B"
  nB=nB+1
  sumGB=sumGB+fg
elif fg>=70:
  lg="C"
  nC=nC+1
  sumGC=sumGC+fg
elif fg>=60:
  lg='D'
  nD=nD+1
  sumGD=sumGD+fg
elif fg<60: # else:
  lg='F'
  nF=nF+1
  sumGF=sumGF+fg

i=f"Final grade: {fg:.2f}, Letter grade: {lg}"
print(i)

# student 1
n=n+1# RAM
i=f"\n\nStudent {n} Exam 1 Grade:"
print(i)
e1Str=input() #
e1=float(e1Str) #

i=f"Student {n} Exam 2 Grade:"
print(i)
e2Str=input()
e2=float(e2Str)

fg=e1*0.4+e2*0.6 # final grade
sumG=sumG+fg

if fg>=90:
  lg="A" # letter grade
  nA=nA+1
  sumGA=sumGA+fg
elif fg>=80:
  lg="B"
  nB=nB+1
  sumGB=sumGB+fg
elif fg>=70:
  lg="C"
  nC=nC+1
  sumGC=sumGC+fg
elif fg>=60:
  lg='D'
  nD=nD+1
  sumGD=sumGD+fg
elif fg<60: # else:
  lg='F'
  nF=nF+1
  sumGF=sumGF+fg

i=f"Final grade: {fg:.2f}, Letter grade: {lg}"
print(i)

# student 1
n=n+1# RAM
i=f"\n\nStudent {n} Exam 1 Grade:"
print(i)
e1Str=input() #
e1=float(e1Str) #

i=f"Student {n} Exam 2 Grade:"
print(i)
e2Str=input()
e2=float(e2Str)

fg=e1*0.4+e2*0.6 # final grade
sumG=sumG+fg

if fg>=90:
  lg="A" # letter grade
  nA=nA+1
  sumGA=sumGA+fg
elif fg>=80:
  lg="B"
  nB=nB+1
  sumGB=sumGB+fg
elif fg>=70:
  lg="C"
  nC=nC+1
  sumGC=sumGC+fg
elif fg>=60:
  lg='D'
  nD=nD+1
  sumGD=sumGD+fg
elif fg<60: # else:
  lg='F'
  nF=nF+1
  sumGF=sumGF+fg

i=f"Final grade: {fg:.2f}, Letter grade: {lg}"
print(i)

# student 1
n=n+1# RAM
i=f"\n\nStudent {n} Exam 1 Grade:"
print(i)
e1Str=input() #
e1=float(e1Str) #

i=f"Student {n} Exam 2 Grade:"
print(i)
e2Str=input()
e2=float(e2Str)

fg=e1*0.4+e2*0.6 # final grade
sumG=sumG+fg

if fg>=90:
  lg="A" # letter grade
  nA=nA+1
  sumGA=sumGA+fg
elif fg>=80:
  lg="B"
  nB=nB+1
  sumGB=sumGB+fg
elif fg>=70:
  lg="C"
  nC=nC+1
  sumGC=sumGC+fg
elif fg>=60:
  lg='D'
  nD=nD+1
  sumGD=sumGD+fg
elif fg<60: # else:
  lg='F'
  nF=nF+1
  sumGF=sumGF+fg

i=f"Final grade: {fg:.2f}, Letter grade: {lg}"
print(i)


# summary information
print("\n\nSummary information")

i=f"Number of students: {n}"
print(i)

r=nA/n
i=f"A: {nA}/{n}, {r:.2%}"
print(i)

i=f"B: {nB}/{n}, {nB/n:.2%}"
print(i)

i=f"C: {nC}/{n}, {nC/n:.2%}"
print(i)

i=f"D: {nD}/{n}, {nD/n:.2%}"
print(i)

i=f"F: {nF}/{n}, {nF/n:.2%}"
print(i)

a=sumG/n
i=f"Average final grade: {a:.2f}"
print(i)

aA=sumGA/nA
i=f"Average final grade for A students: {aA:.2f}"
print(i)

aB=sumGB/nB
i=f"Average final grade for B stuents: {aB:.2f}"
print(i)

aC=sumGC/nC
i=f"Average final grade for C stuents: {aC:.2f}"
print(i)

aD=sumGD/nD
i=f"Average final grade for D stuents: {aD:.2f}"
print(i)

aF=sumGF/nF
i=f"Average final grade for B stuents: {aF:.2f}"
print(i)
# Out:
# Student 1 Exam 1 Grade:
# 96.6
# Student 1 Exam 2 Grade:
# 90.6
# Final grade: 93.00, Letter grade: A
#
#
# Student 2 Exam 1 Grade:
# 80.6
# Student 2 Exam 2 Grade:
# 86.6
# Final grade: 84.20, Letter grade: B
#
#
# Student 3 Exam 1 Grade:
# 70.6
# Student 3 Exam 2 Grade:
# 76.6
# Final grade: 74.20, Letter grade: C
#
#
# Student 4 Exam 1 Grade:
# 66.6
# Student 4 Exam 2 Grade:
# 60.6
# Final grade: 63.00, Letter grade: D
#
#
# Student 5 Exam 1 Grade:
# 50.6
# Student 5 Exam 2 Grade:
# 60.6
# Final grade: 56.60, Letter grade: F
#
#
# Student 6 Exam 1 Grade:
# 90.6
# Student 6 Exam 2 Grade:
# 90.8
# Final grade: 90.72, Letter grade: A
#
#
# Student 7 Exam 1 Grade:
# 89.9
# Student 7 Exam 2 Grade:
# 96.6
# Final grade: 93.92, Letter grade: A
#
#
# Summary information
# Number of students: 7
# A: 3/7, 42.86%
# B: 1/7, 14.29%
# C: 1/7, 14.29%
# D: 1/7, 14.29%
# F: 1/7, 14.29%
# Average final grade: 79.38
# Average final grade for A students: 92.55
# ...
