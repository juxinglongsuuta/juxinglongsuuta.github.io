# %%
# some functions
print("Please input your name:")

nStr=input() # return or result in or prduce a string

print('Please input your age:')
ageStr =input() # it is a string

# convert string into integer
ageInt=int(ageStr)

newAgeInt = ageInt+1 # age after one year

inforStr = "The name is "+nStr +". " + "The currrent age is "+ageStr+". "+ 'The new age is ' +str(newAgeInt) # This is one line.

print(inforStr)
# Out:
# Please input your name:
# Xinglong
# Please input your age:
# 30
# The name is Xinglong. The currrent age is 30. The new age is 31

# %%
# Two rules to define variable (name)
age1 = 20+2 # assignment statement
# 20+2: expression CPU
#
print(age1)# print function age1

# 1. letters numbers _
# 2. First char: letter _
# 2. First char: NOT a number
# Out:
# 22

# %%
age1 = 20+2 #
print(age1)
# Out:
# 22

# %%
_age2=19+2# _age2
print(_age2)
# Out:
# 21

# %%
# invalid
1age = 19 # 1age syntax
# Out:
#   File "/tmp/ipython-input-933291527.py", line 2
#     1age = 19 # 1age syntax
#     ^
# SyntaxError: invalid decimal literal

# %%
# invalid
age# = 19 # age# #
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1441978276.py in <cell line: 0>()
#       1 # invalid
# ----> 2 age# = 19 # age# #
#
# NameError: name 'age' is not defined

# %%
# = assignment operator
# arithmetic operators
# + - * / ** // %
# int float

# %%
r1 = 7/3# expression
print(r1)#
# Out:
# 2.3333333333333335

# %%
r1=7//3
print(r1)
# Out:
# 2

# %%
r1=7%3
print(r1)
# Out:
# 1

# %%
# string format function
p1 = 0.1233
m1 = 2666.999
g1=86.666

print(p1)
print(m1)
print(g1)

# string format function produces a string
s1=f"Interst rate: {p1:.2%}\n\n\n      Balance: ${m1:.2f}\n\t\tGrade: {g1:.6f}"
print(s1)
#\n go to next line \t tab
# Out:
# 0.1233
# 2666.999
# 86.666
# Interst rate: 12.33%
#
#
#       Balance: $2667.00
# 		Grade: 86.666000

# %%
print("Input the current balance: ")
bStr=input()#string

inforStr=f"Currrent balance is: {bStr}"
print(inforStr)
# Out:
# Input the current balance:
# 1000
# Currrent balance is: 1000
