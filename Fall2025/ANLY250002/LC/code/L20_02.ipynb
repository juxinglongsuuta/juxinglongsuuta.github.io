# %%
# %cd "/content/drive/MyDrive/Colab Notebooks/ANLY2500_02_Fall2025/LC/L20"
# Out:
# /content/drive/MyDrive/Colab Notebooks/ANLY2500_02_Fall2025/LC/L20

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/Colab Notebooks/ANLY2500_02_Fall2025/LC/L20'

# %%
# %ls
# Out:
# L20_LCP.ipynb  us-cities-top-1k.csv

# %%
import pandas as pd

# %%
df1=pd.read_csv("us-cities-top-1k.csv")

# %%
df1
# Out:
#               City           State  Population        lat         lon
# 0       Marysville      Washington       63269  48.051764 -122.177082
# 1           Perris      California       72326  33.782519 -117.228648
# 2        Cleveland            Ohio      390113  41.499320  -81.694361
# 3        Worcester   Massachusetts      182544  42.262593  -71.802293
# 4         Columbia  South Carolina      133358  34.000710  -81.034814
# ..             ...             ...         ...        ...         ...
# 995  West New York      New Jersey       52122  40.787879  -74.014306
# 996        Everett   Massachusetts       42935  42.408430  -71.053663
# 997         Linden      New Jersey       41301  40.622048  -74.244590
# 998      Asheville  North Carolina       87236  35.595058  -82.551487
# 999        Compton      California       97877  33.895849 -118.220071
#
# [1000 rows x 5 columns]

# %%
# groupby(): divide the big table (dataframe) into small ones
df1["State"].value_counts()
# Out:
# State
# California              212
# Texas                    83
# Florida                  73
# Illinois                 52
# Massachusetts            36
# Ohio                     33
# Michigan                 31
# Washington               28
# Arizona                  25
# Minnesota                24
# North Carolina           22
# New Jersey               22
# Colorado                 21
# Indiana                  21
# Wisconsin                20
# Utah                     19
# Georgia                  18
# New York                 17
# Virginia                 17
# Tennessee                17
# Missouri                 16
# Connecticut              15
# Oregon                   14
# Pennsylvania             13
# Iowa                     13
# South Carolina           12
# Alabama                  12
# Oklahoma                 11
# Kansas                   11
# Arkansas                 10
# Louisiana                 9
# Idaho                     8
# New Mexico                7
# ...

# %%
r=df1.groupby(by=["State"])

# %%
r.groups.keys()
# Out:
# dict_keys(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'District of Columbia', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico', 'New York', 'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington', 'West Virginia', 'Wisconsin', 'Wyoming'])

# %%
df2=r.get_group("Utah")
# Out:
# /tmp/ipython-input-1624792969.py:1: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   df2=r.get_group("Utah")

# %%
df2
# Out:
#                  City State  Population        lat         lon
# 31              Logan  Utah       48913  41.736980 -111.833836
# 193      South Jordan  Utah       59366  40.562170 -111.929658
# 285         Bountiful  Utah       43023  40.889390 -111.880771
# 381             Provo  Utah      116288  40.233844 -111.658534
# 434      Spanish Fork  Utah       36956  40.114955 -111.654923
# 440      Taylorsville  Utah       60519  40.667725 -111.938826
# 466          Riverton  Utah       40921  40.521893 -111.939102
# 500              Lehi  Utah       54382  40.391617 -111.850766
# 533             Ogden  Utah       84249  41.223000 -111.973830
# 568            Layton  Utah       70790  41.060222 -111.971053
# 603            Murray  Utah       48612  40.666892 -111.887991
# 630             Sandy  Utah       90231  40.564978 -111.838973
# 673  West Valley City  Utah      133579  40.691613 -112.001050
# 676              Orem  Utah       91648  40.296898 -111.694648
# ...

# %%
df2.to_csv("utah.csv",index=True)

# %%
# %ls
# Out:
# L20_LCP.ipynb  us-cities-top-1k.csv  utah.csv

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/Colab Notebooks/ANLY2500_02_Fall2025/LC/L20'

# %%
# %ls
# Out:
# L20_02.ipynb  us-cities-top-1k.csv  utah.csv

# %%
import pandas as pd

# %%
df1=pd.read_csv("us-cities-top-1k.csv")# RAM

# %%
df1
# Out:
#               City           State  Population        lat         lon
# 0       Marysville      Washington       63269  48.051764 -122.177082
# 1           Perris      California       72326  33.782519 -117.228648
# 2        Cleveland            Ohio      390113  41.499320  -81.694361
# 3        Worcester   Massachusetts      182544  42.262593  -71.802293
# 4         Columbia  South Carolina      133358  34.000710  -81.034814
# ..             ...             ...         ...        ...         ...
# 995  West New York      New Jersey       52122  40.787879  -74.014306
# 996        Everett   Massachusetts       42935  42.408430  -71.053663
# 997         Linden      New Jersey       41301  40.622048  -74.244590
# 998      Asheville  North Carolina       87236  35.595058  -82.551487
# 999        Compton      California       97877  33.895849 -118.220071
#
# [1000 rows x 5 columns]

# %%
df1.columns
# Out:
# Index(['City', 'State', 'Population', 'lat', 'lon'], dtype='object')

# %%
# groupby() and for loop
# groupby() will work on table
# divide a table into small ones (tables)

# %%
r=df1.groupby(by=["State"])# RAM

# %%
r.get_group("Texas")
# Out:
# /tmp/ipython-input-1164812433.py:1: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   r.get_group("Texas")
#                      City  State  Population        lat         lon
# 20                Lubbock  Texas      239538  33.577863 -101.855166
# 28                Rowlett  Texas       58043  32.902902  -96.563880
# 38   North Richland Hills  Texas       67317  32.834295  -97.228903
# 59                 Dallas  Texas     1257676  32.776664  -96.796988
# 114             Texarkana  Texas       37442  33.425125  -94.047688
# ..                    ...    ...         ...        ...         ...
# 921             Arlington  Texas      379577  32.735687  -97.108066
# 922            Lewisville  Texas      101074  33.046233  -96.994174
# 963           League City  Texas       90983  29.507454  -95.094930
# ...

# %%
df1['State'].unique() # RAM
# Out:
# array(['Washington', 'California', 'Ohio', 'Massachusetts',
#        'South Carolina', 'Connecticut', 'Minnesota', 'Michigan',
#        'Louisiana', 'Idaho', 'Indiana', 'Georgia', 'Colorado', 'Florida',
#        'Illinois', 'Virginia', 'Texas', 'Kansas', 'Mississippi',
#        'North Carolina', 'Missouri', 'New Mexico', 'Alabama', 'Utah',
#        'Pennsylvania', 'New York', 'Wisconsin', 'Arkansas',
#        'Rhode Island', 'Iowa', 'Nevada', 'Tennessee', 'Wyoming',
#        'Maryland', 'North Dakota', 'Oregon', 'Arizona', 'Maine',
#        'Nebraska', 'New Jersey', 'Montana', 'Oklahoma', 'West Virginia',
#        'South Dakota', 'District of Columbia', 'New Hampshire', 'Alaska',
#        'Delaware', 'Kentucky', 'Hawaii', 'Vermont'], dtype=object)

# %%
r.groups.keys()
# Out:
# dict_keys(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'District of Columbia', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico', 'New York', 'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington', 'West Virginia', 'Wisconsin', 'Wyoming'])

# %%
len(df1['State'].unique())
# Out:
# 51

# %%
len(r)
# Out:
# 51

# %%
r=df1.groupby(by=["State"])# 51 in r
states=["Nevada",'Utah',"Texas"]
n=len(states)# RAM
print(f"There are {n} states.")

for i in states:# i="Nevada" i="Utah" i="Texas"
  print("\n\nOne iteration")
  print(f"The current state is: {i}")
  sdf=r.get_group(i)# table RAM
  sdf=sdf.sort_values(by=["Population"],ascending=[False])
  #
  sdf.to_csv(f"d1/{i}.csv",index=False)
  print(sdf.head(3))
# Out:
# There are 3 states.
#
#
# One iteration
# The current state is: Nevada
#           City   State  Population        lat         lon
# 712  Las Vegas  Nevada      603488  36.169941 -115.139830
# 46   Henderson  Nevada      270811  36.039525 -114.981721
# 110       Reno  Nevada      233294  39.529633 -119.813803
#
#
# One iteration
# The current state is: Utah
#                  City State  Population        lat         lon
# 964    Salt Lake City  Utah      191180  40.760779 -111.891047
# 673  West Valley City  Utah      133579  40.691613 -112.001050
# 381             Provo  Utah      116288  40.233844 -111.658534
#
#
# One iteration
# The current state is: Texas
#             City  State  Population        lat        lon
# 646      Houston  Texas     2195914  29.760427 -95.369803
# 153  San Antonio  Texas     1409019  29.424122 -98.493628
# 59        Dallas  Texas     1257676  32.776664 -96.796988
# ...

# %%
r=df1.groupby(by=["State"])# 51 in r
#states=["Nevada",'Utah',"Texas"]
states=r.groups.keys()
n=len(states)# RAM
print(f"There are {n} states.")

for i in states:# i="Nevada" i="Utah" i="Texas"
  print("\n\nOne iteration")
  print(f"The current state is: {i}")
  sdf=r.get_group(i)# table RAM
  sdf=sdf.sort_values(by=["Population"],ascending=[False])
  #
  sdf.to_csv(f"d1/{i}.csv",index=False)
  print(sdf.head(3))
# Out:
# There are 51 states.
#
#
# One iteration
# The current state is: Alabama
#            City    State  Population        lat        lon
# 248  Birmingham  Alabama      212113  33.520661 -86.802490
# 30   Montgomery  Alabama      201332  32.366805 -86.299969
# 388      Mobile  Alabama      194899  30.695366 -88.039891
#
#
# One iteration
# The current state is: Alaska
#           City   State  Population        lat         lon
# 370  Anchorage  Alaska      300950  61.218056 -149.900278
#
#
# One iteration
# The current state is: Arizona
#         City    State  Population        lat         lon
# 966  Phoenix  Arizona     1513367  33.448377 -112.074037
# 167   Tucson  Arizona      526116  32.221743 -110.926479
# 202     Mesa  Arizona      457587  33.415184 -111.831472
#
#
# One iteration
# The current state is: Arkansas
#              City     State  Population        lat        lon
# 680   Little Rock  Arkansas      197357  34.746481 -92.289595
# ...
