# %%
print("Your real name here") # Use your real name and ID
print("Your student ID here")
# Out:
# Your real name here
# Your student ID here

# %%
r = 2 + 3 # This code is called assignment
print(r) # ctrl c to copy. ctrl v to paste.
# Out:
# 5

# %%
r = 2 + 3*2 # This code is called assignment
print(r)
# Out:
# 8

# %%
# Python Programming
# commands

# 2 main resouces
# 1. CPU, Calculation
# 2. RAM (memory): store data

# 3 topics
# 1. Assignment
# 2. Function/method
# 3. simple vs complex varialbe

# Code (statement)
# Comment

# %%
# variable and assignment
# functions
print(4**2)
# print: function/machine
# print(): function call
# parameter ingredients

# 4**2 ** + - / * operators
# 4**2: expression 2+3 CPU
print(16)
# console
print(7)
# print print() ,,,
print(2+3) #
# 2+3
print(5)
# Out:
# 16
# 16
# 7
# 5
# 5

# %%
# variables vs assignment
v1=8
# = assignment operator
# assignment code (statement), assignment
# =
# left v1, always a variable, room card
# right 8 or expression
# Two steps:
# Step 1: 8 CPU stores the final result into RAM
# Step 2: Write the room number or address into v1

# %%
print(v1)
# NO =
# Out:
# 8

# %%
v2=4**2
#
print(v2)
# Out:
# 16
