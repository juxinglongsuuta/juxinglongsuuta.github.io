# %%
print("Input name:")
nStr=input()

print("Input age:") # age is integer
aStr=input()
a = int(aStr)

print("Input meal amount ($):")
mStr=input()
m=float(mStr)

if a<7 or a>70:
  print("Congrat! You get 50% discount!")
  print(f"You need to pay $ {m*0.5:.2f}")
else:
  print("Sorry. You do not get the discount.")
  print(f"You need to pay $ {m:.2f}")
# Out:
# Input name:
# Xinglong
# Input age:
# 71
# Input meal amount ($):
# 20
# Congrat! You get 50% discount!
# You need to pay $ 10.00

# %%
# Math quiz

# define variables counter/accumulator variables
nQ=0 # number of questions
nC=0 # number of correct answers
nW=0 # number of wrong answers
s=0 # final/total score

# questions
import random # use python code written in random

# Q1
n1=random.randint(1,10)  # . Tom's
n2=random.randint(1,10)
gt=n1+n2 # ground truth
nQ=nQ+1 #
i=f"\nQuestion {nQ}: {n1} + {n2} = ?"
print(i)
aStr=input() # string answer string
a=int(aStr) # answer

if gt==a:
  # correct
  print("Correct! Earn 2 points!")
  nC=nC+1
  s=s+2
else:
  # wrong
  print("Wrong! Lose 3 points!")
  nW=nW+1
  s=s-3

# Q2
n1=random.randint(1,10)  # . Tom's
n2=random.randint(1,10)
gt=n1+n2 # ground truth
nQ=nQ+1 #
i=f"\nQuestion {nQ}: {n1} + {n2} = ?"
print(i)
aStr=input() # string answer string
a=int(aStr) # answer

if gt==a:
  # correct
  print("Correct! Earn 2 points!")
  nC=nC+1
  s=s+2
else:
  # wrong
  print("Wrong! Lose 3 points!")
  nW=nW+1
  s=s-3

# Q3
n1=random.randint(1,10)  # . Tom's
n2=random.randint(1,10)
gt=n1+n2 # ground truth
nQ=nQ+1 #
i=f"\nQuestion {nQ}: {n1} + {n2} = ?"
print(i)
aStr=input() # string answer string
a=int(aStr) # answer

if gt==a:
  # correct
  print("Correct! Earn 2 points!")
  nC=nC+1
  s=s+2
else:
  # wrong
  print("Wrong! Lose 3 points!")
  nW=nW+1
  s=s-3

# Q4
n1=random.randint(1,10)  # . Tom's
n2=random.randint(1,10)
gt=n1+n2 # ground truth
nQ=nQ+1 #
i=f"\nQuestion {nQ}: {n1} + {n2} = ?"
print(i)
aStr=input() # string answer string
a=int(aStr) # answer

if gt==a:
  # correct
  print("Correct! Earn 2 points!")
  nC=nC+1
  s=s+2
else:
  # wrong
  print("Wrong! Lose 3 points!")
  nW=nW+1
  s=s-3

# summary
print("\n\nSummary information")
i=f"Number of questions: {nQ}"
print(i)

r=nC/nQ # ratio
i=f"Correct: {nC}/{nQ}, {r:.2%}"
print(i)

i=f"Wrong: {nW}/{nQ}, {nW/nQ:.3%}"
print(i)

i=f"Final score: {s}"
print(i)

if s>0:
  print("Congrats! Positive score!")
elif s==0:
  print("Socre is 0!")
elif s<0:# else:
  print("Sorry! Negative")
# Out:
# Question 1: 7 + 4 = ?
# 11
# Correct! Earn 2 points!
#
# Question 2: 8 + 5 = ?
# 5
# Wrong! Lose 3 points!
#
# Question 3: 5 + 6 = ?
# 6
# Wrong! Lose 3 points!
#
# Question 4: 1 + 2 = ?
# 3
# Correct! Earn 2 points!
#
#
# Summary information
# Number of questions: 4
# Correct: 2/4, 50.00%
# Wrong: 2/4, 50.000%
# Final score: -2
# Sorry! Negative
