# %%
# strings
# a pair of ' '  "  "
# a pair of triple ''' '''   """   """
print('Your read name here') # if you do not use your real, just copy the string here, 0.2 points deducted
print("Your real student id")
print(''' section number ''')
# Out:
# Your read name here
# Your real student id
#  section number

# %%
print("""Please input your name:""")
n = input()
s = '''Hello,''' + n +", Welcome to ANLY 2500 strings!"
print(s)
# Out:
# Please input your name:
# Xinglong Ju
# Hello,Xinglong Ju, Welcome to ANLY 2500 strings!

# %%
# Assignment
# Function
# Simple and complex variables (resources)

# datatypes
# functions print

# datatypes
# hotel (room types, different sizes)
# CPU
# RAM Byte B
# integer: number, whole number, 0,1, -10: 4B simple (cheap)
# float (double): number 1.0 -1.1 0.0: 8B
# boolean: True False, 1B
# string: a pair of ' " complex (expensive)
# "1.0" string is not a number 3B

# functions
# pancakeMaker(i1,i2,i3)
# print
# int(i1) #
# float(i2)
# str(i1)
# input() # always produces a string

# %%
v1=input()
# Out:
# 123

# %%
# int
v1 = 2# code, statement,
v2= 3

# operators + - * / **
v3 = v1+v2
print(v3)

v3=v1/v2
print(v3)

v3=v1**v2
print(v3)
# Out:
# 5
# 0.6666666666666666
# 8

# %%
v1 = 1.2
v2 =1.0
v3=v1-v2
print(v3)
# Out:
# 0.19999999999999996

# %%
print("input age")
ageStr=input()# string

ageInt=int(ageStr)
print(ageInt)
# Out:
# input age
# 30
# 30
