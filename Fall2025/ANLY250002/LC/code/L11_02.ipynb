# %%
# list range()
# list: multiple variable (data)
a=[3,6,8] # list is a big warehouse, multiple items inside it.
print(a)
# Out:
# [3, 6, 8]

# %%
print(a[0])
# Out:
# 3

# %%
print(a[1])
# Out:
# 6

# %%
a[2]=10
print(a)
# Out:
# [3, 6, 10]

# %%
# range() help us generate data
# 1 to 10
# range(start_value,end_value,step)
r=range(1,10,1) # 1 is included, 10 is not, 1-9
print(r)

b=list(r)
print(b)
# Out:
# range(1, 10)
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
r=range(1,10,2) # 1 is included, 10 is not, 1-9
print(r)

b=list(r)
print(b)
# Out:
# range(1, 10, 2)
# [1, 3, 5, 7, 9]

# %%
# student grades

# define variable # counter/accumulator bank accounts
n=0 # number of students
nA=0 #
nB=0
nC=0
nD=0
nF=0

sumG=0 # sum of all final grades
sumGA=0
sumGB=0
sumGC=0
sumGD=0
sumGF=0

sumGE1=0 # sum fo exam 1 grade
sumGE2=0 #

# collect grades

# student 1
n=n+1 # RAM
i=f"\n\nStudent {n} Exam 1 Grade:"
print(i)
ex1Str=input() #
ex1=float(ex1Str)
sumGE1=sumGE1+ex1#

i=f"Student {n} Exam 2 Grade:"
print(i)
ex2Str=input()
ex2=float(ex2Str)
sumGE2=sumGE2+ex2

fg=ex1*0.4+ex2*0.6 # RAM
sumG=sumG+fg

if fg>=90:
  lg="A"
  nA=nA+1
  sumGA=sumGA+fg
elif fg>=80:
  lg='B'
  nB=nB+1
  sumGB=sumGB+fg
elif fg>=70:
  lg="C"
  nC=nC+1
  sumGC=sumGC+fg
elif fg>=60:
  lg='D'
  nD=nD+1
  sumGD=sumGD+fg
elif fg<60:#else:
  lg='F'
  nF=nF+1
  sumGF=sumGF+fg

i=f"Final grade: {fg:.2f}, Letter grade: {lg}"
print(i)

# student 1
n=n+1 # RAM
i=f"\n\nStudent {n} Exam 1 Grade:"
print(i)
ex1Str=input() #
ex1=float(ex1Str)
sumGE1=sumGE1+ex1#

i=f"Student {n} Exam 2 Grade:"
print(i)
ex2Str=input()
ex2=float(ex2Str)
sumGE2=sumGE2+ex2

fg=ex1*0.4+ex2*0.6 # RAM
sumG=sumG+fg

if fg>=90:
  lg="A"
  nA=nA+1
  sumGA=sumGA+fg
elif fg>=80:
  lg='B'
  nB=nB+1
  sumGB=sumGB+fg
elif fg>=70:
  lg="C"
  nC=nC+1
  sumGC=sumGC+fg
elif fg>=60:
  lg='D'
  nD=nD+1
  sumGD=sumGD+fg
elif fg<60:#else:
  lg='F'
  nF=nF+1
  sumGF=sumGF+fg

i=f"Final grade: {fg:.2f}, Letter grade: {lg}"
print(i)

# student 1
n=n+1 # RAM
i=f"\n\nStudent {n} Exam 1 Grade:"
print(i)
ex1Str=input() #
ex1=float(ex1Str)
sumGE1=sumGE1+ex1#

i=f"Student {n} Exam 2 Grade:"
print(i)
ex2Str=input()
ex2=float(ex2Str)
sumGE2=sumGE2+ex2

fg=ex1*0.4+ex2*0.6 # RAM
sumG=sumG+fg

if fg>=90:
  lg="A"
  nA=nA+1
  sumGA=sumGA+fg
elif fg>=80:
  lg='B'
  nB=nB+1
  sumGB=sumGB+fg
elif fg>=70:
  lg="C"
  nC=nC+1
  sumGC=sumGC+fg
elif fg>=60:
  lg='D'
  nD=nD+1
  sumGD=sumGD+fg
elif fg<60:#else:
  lg='F'
  nF=nF+1
  sumGF=sumGF+fg

i=f"Final grade: {fg:.2f}, Letter grade: {lg}"
print(i)

# student 1
n=n+1 # RAM
i=f"\n\nStudent {n} Exam 1 Grade:"
print(i)
ex1Str=input() #
ex1=float(ex1Str)
sumGE1=sumGE1+ex1#

i=f"Student {n} Exam 2 Grade:"
print(i)
ex2Str=input()
ex2=float(ex2Str)
sumGE2=sumGE2+ex2

fg=ex1*0.4+ex2*0.6 # RAM
sumG=sumG+fg

if fg>=90:
  lg="A"
  nA=nA+1
  sumGA=sumGA+fg
elif fg>=80:
  lg='B'
  nB=nB+1
  sumGB=sumGB+fg
elif fg>=70:
  lg="C"
  nC=nC+1
  sumGC=sumGC+fg
elif fg>=60:
  lg='D'
  nD=nD+1
  sumGD=sumGD+fg
elif fg<60:#else:
  lg='F'
  nF=nF+1
  sumGF=sumGF+fg

i=f"Final grade: {fg:.2f}, Letter grade: {lg}"
print(i)

# student 1
n=n+1 # RAM
i=f"\n\nStudent {n} Exam 1 Grade:"
print(i)
ex1Str=input() #
ex1=float(ex1Str)
sumGE1=sumGE1+ex1#

i=f"Student {n} Exam 2 Grade:"
print(i)
ex2Str=input()
ex2=float(ex2Str)
sumGE2=sumGE2+ex2

fg=ex1*0.4+ex2*0.6 # RAM
sumG=sumG+fg

if fg>=90:
  lg="A"
  nA=nA+1
  sumGA=sumGA+fg
elif fg>=80:
  lg='B'
  nB=nB+1
  sumGB=sumGB+fg
elif fg>=70:
  lg="C"
  nC=nC+1
  sumGC=sumGC+fg
elif fg>=60:
  lg='D'
  nD=nD+1
  sumGD=sumGD+fg
elif fg<60:#else:
  lg='F'
  nF=nF+1
  sumGF=sumGF+fg

i=f"Final grade: {fg:.2f}, Letter grade: {lg}"
print(i)

# student 1
n=n+1 # RAM
i=f"\n\nStudent {n} Exam 1 Grade:"
print(i)
ex1Str=input() #
ex1=float(ex1Str)
sumGE1=sumGE1+ex1#

i=f"Student {n} Exam 2 Grade:"
print(i)
ex2Str=input()
ex2=float(ex2Str)
sumGE2=sumGE2+ex2

fg=ex1*0.4+ex2*0.6 # RAM
sumG=sumG+fg

if fg>=90:
  lg="A"
  nA=nA+1
  sumGA=sumGA+fg
elif fg>=80:
  lg='B'
  nB=nB+1
  sumGB=sumGB+fg
elif fg>=70:
  lg="C"
  nC=nC+1
  sumGC=sumGC+fg
elif fg>=60:
  lg='D'
  nD=nD+1
  sumGD=sumGD+fg
elif fg<60:#else:
  lg='F'
  nF=nF+1
  sumGF=sumGF+fg

i=f"Final grade: {fg:.2f}, Letter grade: {lg}"
print(i)

# student 1
n=n+1 # RAM
i=f"\n\nStudent {n} Exam 1 Grade:"
print(i)
ex1Str=input() #
ex1=float(ex1Str)
sumGE1=sumGE1+ex1#

i=f"Student {n} Exam 2 Grade:"
print(i)
ex2Str=input()
ex2=float(ex2Str)
sumGE2=sumGE2+ex2

fg=ex1*0.4+ex2*0.6 # RAM
sumG=sumG+fg

if fg>=90:
  lg="A"
  nA=nA+1
  sumGA=sumGA+fg
elif fg>=80:
  lg='B'
  nB=nB+1
  sumGB=sumGB+fg
elif fg>=70:
  lg="C"
  nC=nC+1
  sumGC=sumGC+fg
elif fg>=60:
  lg='D'
  nD=nD+1
  sumGD=sumGD+fg
elif fg<60:#else:
  lg='F'
  nF=nF+1
  sumGF=sumGF+fg

i=f"Final grade: {fg:.2f}, Letter grade: {lg}"
print(i)

# student 1
n=n+1 # RAM
i=f"\n\nStudent {n} Exam 1 Grade:"
print(i)
ex1Str=input() #
ex1=float(ex1Str)
sumGE1=sumGE1+ex1#

i=f"Student {n} Exam 2 Grade:"
print(i)
ex2Str=input()
ex2=float(ex2Str)
sumGE2=sumGE2+ex2

fg=ex1*0.4+ex2*0.6 # RAM
sumG=sumG+fg

if fg>=90:
  lg="A"
  nA=nA+1
  sumGA=sumGA+fg
elif fg>=80:
  lg='B'
  nB=nB+1
  sumGB=sumGB+fg
elif fg>=70:
  lg="C"
  nC=nC+1
  sumGC=sumGC+fg
elif fg>=60:
  lg='D'
  nD=nD+1
  sumGD=sumGD+fg
elif fg<60:#else:
  lg='F'
  nF=nF+1
  sumGF=sumGF+fg

i=f"Final grade: {fg:.2f}, Letter grade: {lg}"
print(i)

# student 1
n=n+1 # RAM
i=f"\n\nStudent {n} Exam 1 Grade:"
print(i)
ex1Str=input() #
ex1=float(ex1Str)
sumGE1=sumGE1+ex1#

i=f"Student {n} Exam 2 Grade:"
print(i)
ex2Str=input()
ex2=float(ex2Str)
sumGE2=sumGE2+ex2

fg=ex1*0.4+ex2*0.6 # RAM
sumG=sumG+fg

if fg>=90:
  lg="A"
  nA=nA+1
  sumGA=sumGA+fg
elif fg>=80:
  lg='B'
  nB=nB+1
  sumGB=sumGB+fg
elif fg>=70:
  lg="C"
  nC=nC+1
  sumGC=sumGC+fg
elif fg>=60:
  lg='D'
  nD=nD+1
  sumGD=sumGD+fg
elif fg<60:#else:
  lg='F'
  nF=nF+1
  sumGF=sumGF+fg

i=f"Final grade: {fg:.2f}, Letter grade: {lg}"
print(i)

# summary inforamtion
i=f"Number of students: {n}"
print(i)

a=sumG/n
i=f"Average final grade: {a:.2f}"
print(i)

aE1=sumGE1/n
i=f"Average Exam 1 grade: {aE1:.2f}"
print(i)

aE2=sumGE2/n
i=f"Average Exam 2 grade: {aE2:.2f}"
print(i)

aA=sumGA/nA
i=f"Average final for A: {aA:.2f}"
print(i)

aB=sumGB/nB
i=f"Average final for B: {aB:.2f}"
print(i)

aC=sumGC/nC
i=f"Average final for C: {aC:.2f}"
print(i)

aD=sumGD/nD
i=f"Average final for D: {aD:.2f}"
print(i)

aF=sumGF/nF
i=f"Average final for F: {aF:.2f}"
print(i)

r=nA/n
i=f"A: {nA}/{n}, {r:.2%}"
print(i)

r=nB/n
i=f"B: {nB}/{n}, {r:.2%}"
print(i)

r=nC/n
i=f"C: {nC}/{n}, {r:.2%}"
print(i)

r=nD/n
i=f"D: {nD}/{n}, {r:.2%}"
print(i)

r=nF/n
i=f"F: {nF}/{n}, {r:.2%}"
print(i)
# Out:
# Student 1 Exam 1 Grade:
# 96.6
# Student 1 Exam 2 Grade:
# 80.6
# Final grade: 87.00, Letter grade: B
#
#
# Student 2 Exam 1 Grade:
# 80.6
# Student 2 Exam 2 Grade:
# 90.6
# Final grade: 86.60, Letter grade: B
#
#
# Student 3 Exam 1 Grade:
# 96.6
# Student 3 Exam 2 Grade:
# 90.6
# Final grade: 93.00, Letter grade: A
#
#
# Student 4 Exam 1 Grade:
# 80.6
# Student 4 Exam 2 Grade:
# 69.6
# Final grade: 74.00, Letter grade: C
#
#
# Student 5 Exam 1 Grade:
# 60.3
# Student 5 Exam 2 Grade:
# 60
# Final grade: 60.12, Letter grade: D
#
#
# Student 6 Exam 1 Grade:
# 56
# Student 6 Exam 2 Grade:
# 45
# Final grade: 49.40, Letter grade: F
#
#
# Student 7 Exam 1 Grade:
# 96.6
# Student 7 Exam 2 Grade:
# 90.6
# Final grade: 93.00, Letter grade: A
#
#
# Student 8 Exam 1 Grade:
# 86.6
# Student 8 Exam 2 Grade:
# 87.6
# Final grade: 87.20, Letter grade: B
#
#
# Student 9 Exam 1 Grade:
# 80.6
# Student 9 Exam 2 Grade:
# 89.9
# Final grade: 86.18, Letter grade: B
# Number of students: 9
# Average final grade: 79.61
# Average Exam 1 grade: 81.61
# Average Exam 2 grade: 78.28
# Average final for A: 93.00
# Average final for B: 86.74
# Average final for C: 74.00
# Average final for D: 60.12
# Average final for F: 49.40
# A: 2/9, 22.22%
# B: 4/9, 44.44%
# C: 1/9, 11.11%
# D: 1/9, 11.11%
# F: 1/9, 11.11%
